# %% [markdown]
# ## PropertyHub: 2.4 Scraping Condo Links

# %%
# Import libraries
import os
import glob
import time
import pandas as pd
from datetime import datetime
import requests
from requests.adapters import HTTPAdapter, Retry
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, wait

# %%
class GetLinks():
    def __init__(self):
        self.delay_time = 0.1
        
        self.rent_place_type = []
        self.rent_place_name = []
        self.rent_link_name = []
        self.rent_condo_links = []
        self.sale_place_type = []
        self.sale_place_name = []
        self.sale_link_name = []
        self.sale_condo_links = []
        
        self.retries = 5
        self.backoff = 1     # time-out = [0.5, 1, 2, 4, 8]
        self.status_forcelist = [403, 500, 502, 503, 504]
        self.timeout = (10, 10)
        
        # Initialize request session for retries and timeout
        self.s = requests.Session()
        retries = Retry(total=self.retries,
                        backoff_factor=self.backoff,
                        status_forcelist=self.status_forcelist)
        self.s.mount('http://', HTTPAdapter(max_retries=retries))
        self.s.mount('https://', HTTPAdapter(max_retries=retries))
    
    def import_shuffle_df(self, path, num):
        self.location = pd.read_csv(path)
        self.location = self.location[self.location['flag']==num]
        
    def get_condo_links(self, order):
        df_place_link_name = self.location.iloc[order-1,:]
        place_link_name = df_place_link_name['link_name']
        
        print(f"Thread {order}: getting {df_place_link_name['num_rent']+df_place_link_name['num_sale']} links ...")
        
        # Get for-rent links
        if df_place_link_name['num_rent'] != 0:
            try:
                place_link = f'https://propertyhub.in.th/en/condo-for-rent/{place_link_name}'
                # find max page number
                soup = BeautifulSoup(self.s.get(place_link, timeout=self.timeout).content, "html.parser")
                find_max_page = soup.find_all("ul", {"class": "sc-1p20b44-0 IoRRS"})
                try:
                    max_page = int(find_max_page[0].find_all('li')[-2].a['aria-label'].split()[-1])
                except:
                    max_page = 1
                page_links = [place_link + f'/{i+1}' if i!=0 else place_link for i in range(max_page)]
                for page_link in page_links:
                    soup = BeautifulSoup(self.s.get(page_link, timeout=self.timeout).content, "html.parser")
                    find_condo_links = soup.select("a[href*='en/listings/']")
                    for link in find_condo_links:
                        condo_link = 'https://propertyhub.in.th' + link['href']
                        self.rent_place_type.append(df_place_link_name['place_type'])
                        self.rent_place_name.append(df_place_link_name['place_name'])
                        self.rent_link_name.append(df_place_link_name['link_name'])
                        self.rent_condo_links.append(condo_link)
                time.sleep(self.delay_time)
            except:
                print(f"There is an invalid link: {place_link}")

        # Get for-sale links
        if df_place_link_name['num_sale'] != 0:
            try:
                place_link = f'https://propertyhub.in.th/en/condo-for-sale/{place_link_name}'
                # find max page number
                soup = BeautifulSoup(self.s.get(place_link, timeout=self.timeout).content, "html.parser")
                find_max_page = soup.find_all("ul", {"class": "sc-1p20b44-0 IoRRS"})
                try:
                    max_page = int(find_max_page[0].find_all('li')[-2].a['aria-label'].split()[-1])
                except:
                    max_page = 1
                page_links = [place_link + f'/{i+1}' if i!=0 else place_link for i in range(max_page)]
                for page_link in page_links:
                    soup = BeautifulSoup(self.s.get(page_link, timeout=self.timeout).content, "html.parser")
                    find_condo_links = soup.select("a[href*='en/listings/']")
                    for link in find_condo_links:
                        condo_link = 'https://propertyhub.in.th' + link['href']
                        self.sale_place_type.append(df_place_link_name['place_type'])
                        self.sale_place_name.append(df_place_link_name['place_name'])
                        self.sale_link_name.append(df_place_link_name['link_name'])
                        self.sale_condo_links.append(condo_link)
                time.sleep(self.delay_time)
            except:
                print(f"There is an invalid link: {place_link}")

        # Convert to df and remove duplicates
        self.df_rent_condo_links = pd.DataFrame(self.rent_place_type,columns=['place_type'])
        self.df_rent_condo_links['place_name'] = self.rent_place_name
        self.df_rent_condo_links['link_name'] = self.rent_link_name
        self.df_rent_condo_links['condo_link'] = self.rent_condo_links
        self.df_rent_condo_links.drop_duplicates(subset=['condo_link'],keep='first',inplace=True, ignore_index=True)

        self.df_sale_condo_links = pd.DataFrame(self.sale_place_type,columns=['place_type'])
        self.df_sale_condo_links['place_name'] = self.sale_place_name
        self.df_sale_condo_links['link_name'] = self.sale_link_name
        self.df_sale_condo_links['condo_link'] = self.sale_condo_links
        self.df_sale_condo_links.drop_duplicates(subset=['condo_link'],keep='first',inplace=True, ignore_index=True)

        # Export
        self.df_rent_condo_links.to_csv(f"df_rent_condo_links_{order}.csv",index=False)
        self.df_sale_condo_links.to_csv(f"df_sale_condo_links_{order}.csv",index=False)
        
        print(f"Thread {order}: finished !!!")
            
    def join_df(self):
        output_rent_files = glob.glob(os.getcwd()+'/df_rent*.csv')
        output_sale_files = glob.glob(os.getcwd()+'/df_sale*.csv')
        outputs_rent = [pd.read_csv(output_rent_file) for output_rent_file in output_rent_files]
        outputs_sale = [pd.read_csv(output_sale_file) for output_sale_file in output_sale_files]

        # Combine outputs
        output_rent_all = outputs_rent[0]
        for i in range(len(outputs_rent)-1):
            output_rent_all = pd.concat([output_rent_all,outputs_rent[i+1]], axis=0, ignore_index=True)
        output_sale_all = outputs_sale[0]
        for i in range(len(outputs_sale)-1):
            output_sale_all = pd.concat([output_sale_all,outputs_sale[i+1]], axis=0, ignore_index=True)
            
        # Drop duplicates
        output_rent_all.drop_duplicates(subset=['condo_link'],keep='first',inplace=True, ignore_index=True)
        output_sale_all.drop_duplicates(subset=['condo_link'],keep='first',inplace=True, ignore_index=True)
        
        # Print results
        print(f'!!!!!! Finished Scraping Links !!!!!!')
        print(f'for-rent data len: {len(output_rent_all)}')
        print(f'for-sale data len: {len(output_sale_all)}')

        # Export the combine result
        output_rent_all.to_csv(f"{datetime.now().strftime('%Y%m')}_rent_condo_links_4.csv",index=False)
        output_sale_all.to_csv(f"{datetime.now().strftime('%Y%m')}_sale_condo_links_4.csv",index=False)

        # Delete all the unused files
        [os.remove(output_rent_file) for output_rent_file in output_rent_files];
        [os.remove(output_sale_file) for output_sale_file in output_sale_files];

# %%
num = 4
input_path = '/kaggle/input/ph-1-getting-locations'
file_name = 'locations.csv'
locations = pd.read_csv(f"{input_path}/{file_name}")
locations = locations[locations['flag']==num]

thread_num = len(locations)
print(f'Number of threads: {thread_num}')
getlink_threads = [GetLinks() for _ in range(thread_num)]
[getlink_thread.import_shuffle_df(f'{input_path}/{file_name}',num) for getlink_thread in getlink_threads]

threadList = []
with ThreadPoolExecutor() as executor:
    for i in range(thread_num):
        threadList.append(executor.submit(getlink_threads[i].get_condo_links, i+1))
wait(threadList);

getlink_threads[0].join_df()
# Out:
# Number of threads: 774
# Thread 1: getting 4466 links ...
# Thread 2: getting 4406 links ...
# Thread 3: getting 4354 links ...
# Thread 4: getting 4328 links ...
# Thread 5: getting 4308 links ...
# Thread 6: getting 4235 links ...
# Thread 7: getting 4196 links ...
# Thread 8: getting 4009 links ...
# Thread 5: finished !!!
# Thread 9: getting 4001 links ...
# Thread 6: finished !!!
# Thread 10: getting 3929 links ...
# Thread 3: finished !!!
# Thread 11: getting 3876 links ...
# Thread 8: finished !!!
# Thread 12: getting 3868 links ...
# Thread 1: finished !!!
# Thread 13: getting 3848 links ...
# Thread 4: finished !!!
# Thread 14: getting 3819 links ...
# Thread 7: finished !!!
# Thread 15: getting 3780 links ...
# Thread 2: finished !!!
# Thread 16: getting 3742 links ...
# Thread 9: finished !!!
# Thread 17: getting 3733 links ...
# Thread 11: finished !!!
# Thread 18: getting 3664 links ...
# Thread 10: finished !!!
# Thread 19: getting 3577 links ...
# Thread 16: finished !!!
# Thread 20: getting 3537 links ...
# Thread 12: finished !!!
# Thread 21: getting 3534 links ...
# Thread 14: finished !!!
# Thread 22: getting 3524 links ...
# Thread 15: finished !!!
# Thread 23: getting 3501 links ...
# Thread 13: finished !!!
# Thread 24: getting 3459 links ...
# There is an invalid link: https://propertyhub.in.th/en/condo-for-sale/tawanna
# Thread 17: finished !!!
# Thread 25: getting 3397 links ...
# Thread 18: finished !!!
# Thread 26: getting 3360 links ...
# Thread 19: finished !!!
# Thread 27: getting 3342 links ...
# Thread 24: finished !!!
# Thread 28: getting 3310 links ...
# Thread 22: finished !!!
# Thread 29: getting 3287 links ...
# Thread 20: finished !!!
# Thread 30: getting 3240 links ...
# Thread 23: finished !!!
# Thread 31: getting 3134 links ...
# Thread 25: finished !!!
# Thread 32: getting 3108 links ...
# Thread 21: finished !!!
# Thread 33: getting 3102 links ...
# Thread 26: finished !!!
# Thread 34: getting 3098 links ...
# Thread 27: finished !!!
# Thread 35: getting 3077 links ...
# Thread 33: finished !!!
# Thread 36: getting 3062 links ...
# Thread 29: finished !!!
# Thread 37: getting 3056 links ...
# Thread 28: finished !!!
# Thread 38: getting 3017 links ...
# Thread 31: finished !!!
# Thread 39: getting 2976 links ...
# Thread 30: finished !!!
# Thread 40: getting 2968 links ...
# Thread 32: finished !!!
# Thread 41: getting 2920 links ...
# Thread 34: finished !!!
# Thread 42: getting 2874 links ...
# Thread 35: finished !!!
# Thread 43: getting 2863 links ...
# Thread 36: finished !!!
# Thread 44: getting 2821 links ...
# Thread 42: finished !!!
# Thread 45: getting 2715 links ...
# Thread 37: finished !!!
# Thread 46: getting 2700 links ...
# Thread 40: finished !!!
# Thread 47: getting 2694 links ...
# Thread 39: finished !!!
# Thread 48: getting 2681 links ...
# Thread 43: finished !!!
# Thread 49: getting 2661 links ...
# Thread 41: finished !!!
# Thread 50: getting 2653 links ...
# Thread 38: finished !!!
# Thread 51: getting 2624 links ...
# Thread 44: finished !!!
# Thread 52: getting 2617 links ...
# Thread 48: finished !!!
# Thread 53: getting 2603 links ...
# Thread 46: finished !!!
# Thread 54: getting 2589 links ...
# Thread 49: finished !!!
# Thread 55: getting 2566 links ...
# Thread 51: finished !!!
# Thread 56: getting 2547 links ...
# Thread 50: finished !!!
# Thread 57: getting 2530 links ...
# Thread 47: finished !!!
# Thread 58: getting 2507 links ...
# Thread 45: finished !!!
# Thread 59: getting 2501 links ...
# Thread 54: finished !!!
# Thread 60: getting 2430 links ...
# Thread 52: finished !!!
# Thread 61: getting 2414 links ...
# Thread 53: finished !!!
# Thread 62: getting 2404 links ...
# Thread 56: finished !!!
# Thread 63: getting 2395 links ...
# Thread 59: finished !!!
# Thread 64: getting 2362 links ...
# Thread 55: finished !!!
# Thread 65: getting 2349 links ...
# Thread 61: finished !!!
# Thread 66: getting 2347 links ...
# Thread 60: finished !!!
# Thread 67: getting 2308 links ...
# Thread 62: finished !!!
# Thread 68: getting 2290 links ...
# Thread 57: finished !!!
# Thread 69: getting 2286 links ...
# Thread 58: finished !!!
# Thread 70: getting 2271 links ...
# Thread 63: finished !!!
# Thread 71: getting 2245 links ...
# Thread 68: finished !!!
# Thread 72: getting 2241 links ...
# Thread 67: finished !!!
# Thread 73: getting 2239 links ...
# Thread 66: finished !!!
# Thread 74: getting 2225 links ...
# Thread 64: finished !!!
# Thread 75: getting 2150 links ...
# Thread 70: finished !!!
# Thread 76: getting 2149 links ...
# Thread 65: finished !!!
# Thread 77: getting 2144 links ...
# Thread 71: finished !!!
# Thread 78: getting 2142 links ...
# Thread 69: finished !!!
# Thread 79: getting 2108 links ...
# Thread 72: finished !!!
# Thread 80: getting 2084 links ...
# Thread 73: finished !!!
# Thread 81: getting 2052 links ...
# Thread 74: finished !!!
# Thread 82: getting 2033 links ...
# Thread 76: finished !!!
# Thread 83: getting 2015 links ...
# Thread 77: finished !!!
# Thread 84: getting 2007 links ...
# Thread 75: finished !!!
# Thread 85: getting 2005 links ...
# Thread 80: finished !!!
# Thread 86: getting 1995 links ...
# Thread 79: finished !!!
# Thread 87: getting 1990 links ...
# Thread 84: finished !!!
# Thread 88: getting 1940 links ...
# Thread 83: finished !!!
# Thread 89: getting 1926 links ...
# Thread 85: finished !!!
# Thread 90: getting 1875 links ...
# Thread 78: finished !!!
# Thread 91: getting 1860 links ...
# Thread 81: finished !!!
# Thread 92: getting 1836 links ...
# Thread 82: finished !!!
# Thread 93: getting 1828 links ...
# Thread 90: finished !!!
# Thread 94: getting 1826 links ...
# Thread 88: finished !!!
# Thread 95: getting 1813 links ...
# Thread 86: finished !!!
# Thread 96: getting 1791 links ...
# Thread 87: finished !!!
# Thread 97: getting 1788 links ...
# Thread 92: finished !!!
# Thread 98: getting 1729 links ...
# Thread 91: finished !!!
# Thread 99: getting 1716 links ...
# Thread 89: finished !!!
# Thread 100: getting 1707 links ...
# Thread 93: finished !!!
# Thread 101: getting 1674 links ...
# Thread 97: finished !!!
# Thread 102: getting 1671 links ...
# Thread 94: finished !!!
# Thread 103: getting 1635 links ...
# Thread 96: finished !!!
# Thread 104: getting 1591 links ...
# Thread 99: finished !!!
# Thread 105: getting 1577 links ...
# Thread 95: finished !!!
# Thread 106: getting 1567 links ...
# Thread 98: finished !!!
# Thread 107: getting 1552 links ...
# Thread 100: finished !!!
# Thread 108: getting 1547 links ...
# Thread 101: finished !!!
# Thread 109: getting 1541 links ...
# Thread 103: finished !!!
# Thread 110: getting 1531 links ...
# Thread 102: finished !!!
# Thread 111: getting 1513 links ...
# Thread 104: finished !!!
# Thread 112: getting 1508 links ...
# Thread 105: finished !!!
# Thread 113: getting 1508 links ...
# Thread 108: finished !!!
# Thread 114: getting 1504 links ...
# Thread 107: finished !!!
# Thread 115: getting 1498 links ...
# Thread 106: finished !!!
# Thread 116: getting 1492 links ...
# Thread 109: finished !!!
# Thread 117: getting 1492 links ...
# Thread 110: finished !!!
# Thread 118: getting 1487 links ...
# Thread 111: finished !!!
# Thread 119: getting 1483 links ...
# Thread 113: finished !!!
# Thread 120: getting 1474 links ...
# Thread 114: finished !!!
# Thread 121: getting 1453 links ...
# Thread 115: finished !!!
# Thread 122: getting 1451 links ...
# Thread 116: finished !!!
# Thread 123: getting 1434 links ...
# Thread 112: finished !!!
# Thread 124: getting 1433 links ...
# Thread 119: finished !!!
# Thread 125: getting 1407 links ...
# Thread 122: finished !!!
# Thread 126: getting 1405 links ...
# Thread 117: finished !!!
# Thread 127: getting 1397 links ...
# Thread 118: finished !!!
# Thread 128: getting 1387 links ...
# Thread 121: finished !!!
# Thread 129: getting 1377 links ...
# Thread 123: finished !!!
# Thread 130: getting 1363 links ...
# Thread 120: finished !!!
# Thread 131: getting 1353 links ...
# Thread 125: finished !!!
# Thread 132: getting 1339 links ...
# Thread 126: finished !!!
# Thread 133: getting 1323 links ...
# Thread 124: finished !!!
# Thread 134: getting 1303 links ...
# Thread 130: finished !!!
# Thread 135: getting 1301 links ...
# Thread 127: finished !!!
# Thread 136: getting 1291 links ...
# Thread 129: finished !!!
# Thread 137: getting 1288 links ...
# Thread 128: finished !!!
# Thread 138: getting 1285 links ...
# Thread 134: finished !!!
# Thread 139: getting 1284 links ...
# Thread 131: finished !!!
# Thread 140: getting 1255 links ...
# Thread 137: finished !!!
# Thread 141: getting 1248 links ...
# Thread 132: finished !!!
# Thread 142: getting 1226 links ...
# Thread 133: finished !!!
# Thread 143: getting 1224 links ...
# Thread 135: finished !!!
# Thread 144: getting 1192 links ...
# Thread 140: finished !!!
# Thread 145: getting 1191 links ...
# Thread 138: finished !!!
# Thread 146: getting 1174 links ...
# Thread 136: finished !!!
# Thread 147: getting 1159 links ...
# Thread 139: finished !!!
# Thread 148: getting 1157 links ...
# Thread 141: finished !!!
# Thread 149: getting 1148 links ...
# Thread 142: finished !!!
# Thread 150: getting 1147 links ...
# Thread 143: finished !!!
# Thread 151: getting 1144 links ...
# Thread 144: finished !!!
# Thread 152: getting 1143 links ...
# Thread 147: finished !!!
# Thread 153: getting 1121 links ...
# Thread 145: finished !!!
# Thread 154: getting 1121 links ...
# Thread 146: finished !!!
# Thread 155: getting 1095 links ...
# Thread 151: finished !!!
# Thread 156: getting 1076 links ...
# Thread 153: finished !!!
# Thread 157: getting 1072 links ...
# Thread 149: finished !!!
# Thread 158: getting 1057 links ...
# Thread 148: finished !!!
# Thread 159: getting 1049 links ...
# Thread 152: finished !!!
# Thread 160: getting 1038 links ...
# Thread 154: finished !!!
# Thread 161: getting 1037 links ...
# Thread 150: finished !!!
# Thread 162: getting 1033 links ...
# Thread 156: finished !!!
# Thread 163: getting 1027 links ...
# Thread 162: finished !!!
# Thread 164: getting 1025 links ...
# Thread 157: finished !!!
# Thread 165: getting 1006 links ...
# Thread 155: finished !!!
# Thread 166: getting 1006 links ...
# Thread 158: finished !!!
# Thread 167: getting 1005 links ...
# Thread 163: finished !!!
# Thread 168: getting 999 links ...
# Thread 161: finished !!!
# Thread 169: getting 999 links ...
# Thread 159: finished !!!
# Thread 170: getting 992 links ...
# Thread 160: finished !!!
# Thread 171: getting 991 links ...
# Thread 164: finished !!!
# Thread 172: getting 977 links ...
# Thread 165: finished !!!
# Thread 173: getting 973 links ...
# Thread 167: finished !!!
# Thread 174: getting 964 links ...
# Thread 169: finished !!!
# Thread 175: getting 964 links ...
# Thread 170: finished !!!
# Thread 176: getting 962 links ...
# Thread 166: finished !!!
# Thread 177: getting 956 links ...
# Thread 168: finished !!!
# Thread 178: getting 956 links ...
# Thread 172: finished !!!
# Thread 179: getting 945 links ...
# Thread 171: finished !!!
# Thread 180: getting 944 links ...
# Thread 173: finished !!!
# Thread 181: getting 944 links ...
# Thread 174: finished !!!
# Thread 182: getting 931 links ...
# Thread 175: finished !!!
# Thread 183: getting 929 links ...
# Thread 178: finished !!!
# Thread 184: getting 923 links ...
# Thread 177: finished !!!
# Thread 185: getting 917 links ...
# Thread 179: finished !!!
# Thread 186: getting 902 links ...
# Thread 181: finished !!!
# Thread 187: getting 896 links ...
# Thread 176: finished !!!
# Thread 188: getting 878 links ...
# Thread 182: finished !!!
# Thread 189: getting 842 links ...
# Thread 184: finished !!!
# Thread 190: getting 842 links ...
# Thread 180: finished !!!
# Thread 191: getting 841 links ...
# Thread 183: finished !!!
# Thread 192: getting 816 links ...
# Thread 186: finished !!!
# Thread 193: getting 805 links ...
# Thread 185: finished !!!
# Thread 194: getting 799 links ...
# Thread 187: finished !!!
# Thread 195: getting 774 links ...
# Thread 188: finished !!!
# Thread 196: getting 770 links ...
# Thread 190: finished !!!
# Thread 197: getting 766 links ...
# Thread 189: finished !!!
# Thread 198: getting 765 links ...
# Thread 191: finished !!!
# Thread 199: getting 762 links ...
# Thread 193: finished !!!
# Thread 200: getting 761 links ...
# Thread 194: finished !!!
# Thread 201: getting 758 links ...
# Thread 192: finished !!!
# Thread 202: getting 752 links ...
# Thread 197: finished !!!
# Thread 203: getting 750 links ...
# Thread 196: finished !!!
# Thread 204: getting 746 links ...
# Thread 195: finished !!!
# Thread 205: getting 742 links ...
# Thread 201: finished !!!
# Thread 206: getting 738 links ...
# Thread 199: finished !!!
# Thread 207: getting 714 links ...
# Thread 200: finished !!!
# Thread 208: getting 706 links ...
# Thread 204: finished !!!
# Thread 209: getting 697 links ...
# Thread 205: finished !!!
# Thread 210: getting 691 links ...
# Thread 203: finished !!!
# Thread 211: getting 686 links ...
# Thread 202: finished !!!
# Thread 212: getting 660 links ...
# Thread 198: finished !!!
# Thread 213: getting 655 links ...
# Thread 207: finished !!!
# Thread 214: getting 652 links ...
# Thread 208: finished !!!
# Thread 215: getting 652 links ...
# Thread 210: finished !!!
# Thread 216: getting 639 links ...
# Thread 213: finished !!!
# Thread 217: getting 631 links ...
# Thread 206: finished !!!
# Thread 218: getting 628 links ...
# Thread 211: finished !!!
# Thread 219: getting 626 links ...
# Thread 216: finished !!!
# Thread 220: getting 624 links ...
# Thread 209: finished !!!
# Thread 221: getting 621 links ...
# Thread 212: finished !!!
# Thread 222: getting 620 links ...
# Thread 214: finished !!!
# Thread 223: getting 614 links ...
# Thread 215: finished !!!
# Thread 224: getting 614 links ...
# Thread 217: finished !!!
# Thread 225: getting 613 links ...
# Thread 218: finished !!!
# Thread 226: getting 612 links ...
# Thread 222: finished !!!
# Thread 227: getting 607 links ...
# Thread 221: finished !!!
# Thread 228: getting 601 links ...
# Thread 220: finished !!!
# Thread 229: getting 599 links ...
# Thread 223: finished !!!
# Thread 230: getting 599 links ...
# Thread 219: finished !!!
# Thread 231: getting 592 links ...
# Thread 224: finished !!!
# Thread 232: getting 590 links ...
# Thread 225: finished !!!
# Thread 233: getting 589 links ...
# Thread 229: finished !!!
# Thread 234: getting 588 links ...
# Thread 226: finished !!!
# Thread 235: getting 586 links ...
# Thread 230: finished !!!
# Thread 236: getting 585 links ...
# Thread 227: finished !!!
# Thread 237: getting 585 links ...
# Thread 228: finished !!!
# Thread 238: getting 585 links ...
# Thread 231: finished !!!
# Thread 239: getting 567 links ...
# Thread 233: finished !!!
# Thread 240: getting 564 links ...
# Thread 234: finished !!!
# Thread 241: getting 557 links ...
# Thread 232: finished !!!
# Thread 242: getting 557 links ...
# Thread 235: finished !!!
# Thread 243: getting 554 links ...
# Thread 236: finished !!!
# Thread 244: getting 552 links ...
# Thread 241: finished !!!
# Thread 245: getting 550 links ...
# Thread 242: finished !!!
# Thread 246: getting 543 links ...
# Thread 238: finished !!!
# Thread 247: getting 542 links ...
# Thread 239: finished !!!
# Thread 248: getting 539 links ...
# Thread 240: finished !!!
# Thread 249: getting 539 links ...
# Thread 244: finished !!!
# Thread 250: getting 538 links ...
# Thread 237: finished !!!
# Thread 251: getting 535 links ...
# Thread 243: finished !!!
# Thread 252: getting 531 links ...
# Thread 246: finished !!!
# Thread 253: getting 529 links ...
# Thread 249: finished !!!
# Thread 254: getting 526 links ...
# Thread 248: finished !!!
# Thread 255: getting 525 links ...
# Thread 247: finished !!!
# Thread 256: getting 525 links ...
# Thread 251: finished !!!
# Thread 257: getting 522 links ...
# Thread 245: finished !!!
# Thread 258: getting 521 links ...
# Thread 256: finished !!!
# Thread 259: getting 521 links ...
# Thread 250: finished !!!
# Thread 260: getting 514 links ...
# Thread 255: finished !!!
# Thread 261: getting 508 links ...
# Thread 259: finished !!!
# Thread 262: getting 498 links ...
# Thread 253: finished !!!
# Thread 263: getting 494 links ...
# Thread 254: finished !!!
# Thread 264: getting 493 links ...
# Thread 252: finished !!!
# Thread 265: getting 492 links ...
# Thread 260: finished !!!
# Thread 266: getting 490 links ...
# Thread 257: finished !!!
# Thread 267: getting 489 links ...
# Thread 258: finished !!!
# Thread 268: getting 482 links ...
# Thread 264: finished !!!
# Thread 269: getting 480 links ...
# Thread 262: finished !!!
# Thread 270: getting 479 links ...
# Thread 265: finished !!!
# Thread 271: getting 478 links ...
# Thread 263: finished !!!
# Thread 272: getting 478 links ...
# Thread 266: finished !!!
# Thread 273: getting 476 links ...
# Thread 261: finished !!!
# Thread 274: getting 476 links ...
# Thread 268: finished !!!
# Thread 275: getting 476 links ...
# Thread 270: finished !!!
# Thread 276: getting 476 links ...
# Thread 267: finished !!!
# Thread 277: getting 476 links ...
# Thread 273: finished !!!
# Thread 278: getting 465 links ...
# Thread 269: finished !!!
# Thread 279: getting 465 links ...
# Thread 271: finished !!!
# Thread 280: getting 462 links ...
# Thread 276: finished !!!
# Thread 281: getting 461 links ...
# Thread 272: finished !!!
# Thread 282: getting 454 links ...
# Thread 277: finished !!!
# Thread 283: getting 450 links ...
# Thread 275: finished !!!
# Thread 284: getting 450 links ...
# Thread 274: finished !!!
# Thread 285: getting 447 links ...
# Thread 279: finished !!!
# Thread 286: getting 445 links ...
# Thread 283: finished !!!
# Thread 287: getting 444 links ...
# Thread 278: finished !!!
# Thread 288: getting 444 links ...
# Thread 282: finished !!!
# Thread 289: getting 444 links ...
# Thread 281: finished !!!
# Thread 290: getting 441 links ...
# Thread 280: finished !!!
# Thread 291: getting 439 links ...
# Thread 284: finished !!!
# Thread 292: getting 432 links ...
# Thread 286: finished !!!
# Thread 293: getting 430 links ...
# Thread 291: finished !!!
# Thread 294: getting 430 links ...
# Thread 288: finished !!!
# Thread 295: getting 430 links ...
# Thread 285: finished !!!
# Thread 296: getting 430 links ...
# Thread 290: finished !!!
# Thread 297: getting 429 links ...
# Thread 289: finished !!!
# Thread 298: getting 425 links ...
# Thread 287: finished !!!
# Thread 299: getting 420 links ...
# Thread 296: finished !!!
# Thread 300: getting 418 links ...
# Thread 297: finished !!!
# Thread 301: getting 415 links ...
# Thread 293: finished !!!
# Thread 302: getting 410 links ...
# Thread 299: finished !!!
# Thread 303: getting 409 links ...
# Thread 292: finished !!!
# Thread 304: getting 409 links ...
# Thread 298: finished !!!
# Thread 305: getting 405 links ...
# Thread 295: finished !!!
# Thread 306: getting 405 links ...
# Thread 294: finished !!!
# Thread 307: getting 405 links ...
# Thread 302: finished !!!
# Thread 308: getting 400 links ...
# Thread 303: finished !!!
# Thread 309: getting 391 links ...
# Thread 304: finished !!!
# Thread 310: getting 384 links ...
# Thread 301: finished !!!
# Thread 311: getting 381 links ...
# Thread 308: finished !!!
# Thread 312: getting 378 links ...
# Thread 300: finished !!!
# Thread 313: getting 375 links ...
# Thread 307: finished !!!
# Thread 314: getting 374 links ...
# Thread 310: finished !!!
# Thread 315: getting 374 links ...
# Thread 311: finished !!!
# Thread 316: getting 369 links ...
# Thread 305: finished !!!
# Thread 317: getting 369 links ...
# Thread 315: finished !!!
# Thread 318: getting 368 links ...
# Thread 309: finished !!!
# Thread 319: getting 363 links ...
# Thread 306: finished !!!
# Thread 320: getting 360 links ...
# Thread 314: finished !!!
# Thread 321: getting 360 links ...
# Thread 318: finished !!!
# Thread 322: getting 359 links ...
# Thread 316: finished !!!
# Thread 323: getting 356 links ...
# Thread 312: finished !!!
# Thread 324: getting 349 links ...
# Thread 313: finished !!!
# Thread 325: getting 348 links ...
# Thread 320: finished !!!
# Thread 326: getting 334 links ...
# Thread 325: finished !!!
# Thread 327: getting 334 links ...
# Thread 322: finished !!!
# Thread 328: getting 333 links ...
# Thread 317: finished !!!
# Thread 329: getting 328 links ...
# Thread 321: finished !!!
# Thread 330: getting 326 links ...
# Thread 324: finished !!!
# Thread 331: getting 322 links ...
# Thread 319: finished !!!
# Thread 332: getting 321 links ...
# Thread 323: finished !!!
# Thread 333: getting 319 links ...
# Thread 329: finished !!!
# Thread 334: getting 319 links ...
# Thread 331: finished !!!
# Thread 335: getting 312 links ...
# Thread 330: finished !!!
# Thread 336: getting 309 links ...
# Thread 327: finished !!!
# Thread 337: getting 298 links ...
# Thread 336: finished !!!
# Thread 338: getting 297 links ...
# Thread 333: finished !!!
# Thread 339: getting 292 links ...
# Thread 335: finished !!!
# Thread 340: getting 288 links ...
# Thread 328: finished !!!
# Thread 341: getting 288 links ...
# Thread 332: finished !!!
# Thread 342: getting 285 links ...
# Thread 326: finished !!!
# Thread 343: getting 282 links ...
# Thread 337: finished !!!
# Thread 344: getting 276 links ...
# Thread 334: finished !!!
# Thread 345: getting 274 links ...
# Thread 339: finished !!!
# Thread 346: getting 274 links ...
# Thread 344: finished !!!
# Thread 347: getting 274 links ...
# Thread 342: finished !!!
# Thread 348: getting 273 links ...
# Thread 341: finished !!!
# Thread 349: getting 273 links ...
# Thread 343: finished !!!
# Thread 350: getting 273 links ...
# Thread 347: finished !!!
# Thread 351: getting 270 links ...
# Thread 346: finished !!!
# Thread 352: getting 270 links ...
# Thread 338: finished !!!
# Thread 353: getting 265 links ...
# Thread 340: finished !!!
# Thread 354: getting 263 links ...
# Thread 349: finished !!!
# Thread 355: getting 262 links ...
# Thread 345: finished !!!
# Thread 356: getting 260 links ...
# Thread 348: finished !!!
# Thread 357: getting 259 links ...
# Thread 350: finished !!!
# Thread 358: getting 259 links ...
# Thread 354: finished !!!
# Thread 359: getting 254 links ...
# Thread 352: finished !!!
# Thread 360: getting 253 links ...
# Thread 351: finished !!!
# Thread 361: getting 242 links ...
# Thread 360: finished !!!
# Thread 362: getting 237 links ...
# Thread 359: finished !!!
# Thread 363: getting 235 links ...
# Thread 356: finished !!!
# Thread 364: getting 226 links ...
# Thread 358: finished !!!
# Thread 365: getting 223 links ...
# Thread 353: finished !!!
# Thread 366: getting 218 links ...
# Thread 364: finished !!!
# Thread 367: getting 218 links ...
# Thread 355: finished !!!
# Thread 368: getting 217 links ...
# Thread 366: finished !!!
# Thread 369: getting 216 links ...
# Thread 357: finished !!!
# Thread 370: getting 215 links ...
# Thread 361: finished !!!
# Thread 371: getting 214 links ...
# Thread 363: finished !!!
# Thread 372: getting 212 links ...
# Thread 362: finished !!!
# Thread 373: getting 210 links ...
# Thread 371: finished !!!
# Thread 374: getting 202 links ...
# Thread 365: finished !!!
# Thread 375: getting 198 links ...
# Thread 372: finished !!!
# Thread 376: getting 194 links ...
# Thread 368: finished !!!
# Thread 377: getting 192 links ...
# Thread 370: finished !!!
# Thread 378: getting 192 links ...
# Thread 367: finished !!!
# Thread 379: getting 191 links ...
# Thread 378: finished !!!
# Thread 380: getting 189 links ...
# Thread 374: finished !!!
# Thread 381: getting 186 links ...
# Thread 373: finished !!!
# Thread 382: getting 184 links ...
# Thread 369: finished !!!
# Thread 383: getting 183 links ...
# Thread 376: finished !!!
# Thread 384: getting 183 links ...
# Thread 375: finished !!!
# Thread 385: getting 183 links ...
# Thread 379: finished !!!
# Thread 386: getting 179 links ...
# Thread 381: finished !!!
# Thread 387: getting 176 links ...
# Thread 380: finished !!!
# Thread 388: getting 168 links ...
# Thread 382: finished !!!
# Thread 389: getting 167 links ...
# Thread 383: finished !!!
# Thread 390: getting 164 links ...
# Thread 384: finished !!!
# Thread 391: getting 163 links ...
# Thread 389: finished !!!
# Thread 392: getting 161 links ...
# Thread 386: finished !!!
# Thread 393: getting 154 links ...
# Thread 387: finished !!!
# Thread 394: getting 154 links ...
# Thread 390: finished !!!
# Thread 395: getting 151 links ...
# Thread 395: finished !!!
# Thread 396: getting 149 links ...
# Thread 391: finished !!!
# Thread 397: getting 149 links ...
# Thread 377: finished !!!
# Thread 398: getting 144 links ...
# Thread 388: finished !!!
# Thread 399: getting 144 links ...
# Thread 385: finished !!!
# Thread 400: getting 142 links ...
# Thread 394: finished !!!
# Thread 401: getting 141 links ...
# Thread 399: finished !!!
# Thread 402: getting 139 links ...
# Thread 392: finished !!!
# Thread 403: getting 138 links ...
# Thread 401: finished !!!
# Thread 404: getting 134 links ...
# Thread 403: finished !!!
# Thread 405: getting 130 links ...
# Thread 402: finished !!!
# Thread 406: getting 124 links ...
# Thread 393: finished !!!
# Thread 407: getting 123 links ...
# Thread 400: finished !!!
# Thread 408: getting 122 links ...
# Thread 405: finished !!!
# Thread 409: getting 121 links ...
# Thread 397: finished !!!
# Thread 410: getting 119 links ...
# Thread 406: finished !!!
# Thread 411: getting 118 links ...
# Thread 396: finished !!!
# Thread 412: getting 114 links ...
# Thread 408: finished !!!
# Thread 413: getting 112 links ...
# Thread 398: finished !!!
# Thread 414: getting 112 links ...
# Thread 404: finished !!!
# Thread 415: getting 110 links ...
# Thread 407: finished !!!
# Thread 416: getting 109 links ...
# Thread 412: finished !!!
# Thread 417: getting 108 links ...
# Thread 411: finished !!!
# Thread 418: getting 106 links ...
# Thread 414: finished !!!
# Thread 419: getting 106 links ...
# Thread 417: finished !!!
# Thread 420: getting 104 links ...
# Thread 415: finished !!!
# Thread 421: getting 103 links ...
# Thread 410: finished !!!
# Thread 422: getting 102 links ...
# Thread 416: finished !!!
# Thread 423: getting 102 links ...
# Thread 413: finished !!!
# Thread 424: getting 102 links ...
# Thread 418: finished !!!
# Thread 425: getting 101 links ...
# Thread 420: finished !!!
# Thread 426: getting 100 links ...
# Thread 422: finished !!!
# Thread 427: getting 100 links ...
# Thread 425: finished !!!
# Thread 428: getting 99 links ...
# Thread 409: finished !!!
# Thread 429: getting 98 links ...
# Thread 424: finished !!!
# Thread 430: getting 97 links ...
# Thread 428: finished !!!
# Thread 431: getting 97 links ...
# Thread 421: finished !!!
# Thread 432: getting 95 links ...
# Thread 419: finished !!!
# Thread 433: getting 94 links ...
# Thread 429: finished !!!
# Thread 434: getting 93 links ...
# Thread 423: finished !!!
# Thread 435: getting 93 links ...
# Thread 432: finished !!!
# Thread 436: getting 92 links ...
# Thread 433: finished !!!
# Thread 437: getting 91 links ...
# Thread 435: finished !!!
# Thread 438: getting 90 links ...
# Thread 431: finished !!!
# Thread 439: getting 90 links ...
# Thread 427: finished !!!
# Thread 440: getting 90 links ...
# Thread 436: finished !!!
# Thread 441: getting 88 links ...
# Thread 439: finished !!!
# Thread 442: getting 86 links ...
# Thread 430: finished !!!
# Thread 443: getting 85 links ...
# Thread 426: finished !!!
# Thread 444: getting 82 links ...
# Thread 437: finished !!!
# Thread 445: getting 81 links ...
# Thread 443: finished !!!
# Thread 446: getting 81 links ...
# Thread 434: finished !!!
# Thread 447: getting 81 links ...
# Thread 438: finished !!!
# Thread 448: getting 76 links ...
# Thread 444: finished !!!
# Thread 449: getting 71 links ...
# Thread 440: finished !!!
# Thread 450: getting 71 links ...
# Thread 442: finished !!!
# Thread 451: getting 67 links ...
# Thread 450: finished !!!
# Thread 452: getting 66 links ...
# Thread 446: finished !!!
# Thread 453: getting 62 links ...
# Thread 451: finished !!!
# Thread 454: getting 62 links ...
# Thread 449: finished !!!
# Thread 455: getting 59 links ...
# Thread 441: finished !!!
# Thread 456: getting 59 links ...
# Thread 448: finished !!!
# Thread 457: getting 58 links ...
# Thread 454: finished !!!
# Thread 458: getting 57 links ...
# Thread 453: finished !!!
# Thread 459: getting 57 links ...
# Thread 452: finished !!!
# Thread 460: getting 57 links ...
# Thread 457: finished !!!
# Thread 461: getting 57 links ...
# Thread 460: finished !!!
# Thread 462: getting 57 links ...
# Thread 461: finished !!!
# Thread 463: getting 57 links ...
# Thread 447: finished !!!
# Thread 464: getting 57 links ...
# Thread 458: finished !!!
# Thread 465: getting 57 links ...
# Thread 455: finished !!!
# Thread 466: getting 56 links ...
# Thread 463: finished !!!
# Thread 467: getting 56 links ...
# Thread 465: finished !!!
# Thread 468: getting 56 links ...
# Thread 462: finished !!!
# Thread 469: getting 56 links ...
# Thread 445: finished !!!
# Thread 470: getting 56 links ...
# Thread 464: finished !!!
# Thread 471: getting 56 links ...
# Thread 467: finished !!!
# Thread 472: getting 56 links ...
# Thread 468: finished !!!
# Thread 473: getting 56 links ...
# Thread 456: finished !!!
# Thread 474: getting 56 links ...
# Thread 466: finished !!!
# Thread 475: getting 56 links ...
# Thread 473: finished !!!
# Thread 476: getting 55 links ...
# Thread 470: finished !!!
# Thread 477: getting 54 links ...
# Thread 475: finished !!!
# Thread 478: getting 54 links ...
# Thread 474: finished !!!
# Thread 479: getting 53 links ...
# Thread 471: finished !!!
# Thread 480: getting 53 links ...
# Thread 459: finished !!!
# Thread 481: getting 53 links ...
# Thread 477: finished !!!
# Thread 482: getting 53 links ...
# Thread 476: finished !!!
# Thread 483: getting 52 links ...
# Thread 469: finished !!!
# Thread 484: getting 52 links ...
# Thread 480: finished !!!
# Thread 485: getting 51 links ...
# Thread 479: finished !!!
# Thread 486: getting 51 links ...
# Thread 481: finished !!!
# Thread 487: getting 51 links ...
# Thread 486: finished !!!
# Thread 488: getting 51 links ...
# Thread 472: finished !!!
# Thread 489: getting 50 links ...
# Thread 488: finished !!!
# Thread 490: getting 50 links ...
# Thread 487: finished !!!
# Thread 491: getting 50 links ...
# Thread 478: finished !!!
# Thread 492: getting 50 links ...
# Thread 484: finished !!!
# Thread 493: getting 50 links ...
# Thread 482: finished !!!
# Thread 494: getting 50 links ...
# Thread 492: finished !!!
# Thread 495: getting 50 links ...
# Thread 494: finished !!!
# Thread 496: getting 50 links ...
# Thread 485: finished !!!
# Thread 497: getting 50 links ...
# Thread 493: finished !!!
# Thread 498: getting 49 links ...
# Thread 496: finished !!!
# Thread 499: getting 49 links ...
# Thread 490: finished !!!
# Thread 500: getting 48 links ...
# Thread 489: finished !!!
# Thread 501: getting 47 links ...
# Thread 483: finished !!!
# Thread 502: getting 46 links ...
# Thread 498: finished !!!
# Thread 503: getting 46 links ...
# Thread 499: finished !!!
# Thread 504: getting 46 links ...
# Thread 500: finished !!!
# Thread 505: getting 45 links ...
# Thread 495: finished !!!
# Thread 506: getting 45 links ...
# Thread 501: finished !!!
# Thread 507: getting 45 links ...
# Thread 502: finished !!!
# Thread 508: getting 45 links ...
# Thread 505: finished !!!
# Thread 509: getting 45 links ...
# Thread 497: finished !!!
# Thread 510: getting 45 links ...
# Thread 491: finished !!!
# Thread 511: getting 45 links ...
# Thread 509: finished !!!
# Thread 512: getting 45 links ...
# Thread 510: finished !!!
# Thread 513: getting 45 links ...
# Thread 506: finished !!!
# Thread 514: getting 45 links ...
# Thread 507: finished !!!
# Thread 515: getting 45 links ...
# Thread 508: finished !!!
# Thread 516: getting 45 links ...
# Thread 514: finished !!!
# Thread 517: getting 45 links ...
# Thread 503: finished !!!
# Thread 518: getting 44 links ...
# Thread 515: finished !!!
# Thread 519: getting 43 links ...
# Thread 512: finished !!!
# Thread 520: getting 43 links ...
# Thread 511: finished !!!
# Thread 521: getting 43 links ...
# Thread 521: finished !!!
# Thread 522: getting 43 links ...
# Thread 517: finished !!!
# Thread 523: getting 42 links ...
# Thread 504: finished !!!
# Thread 524: getting 42 links ...
# Thread 516: finished !!!
# Thread 525: getting 42 links ...
# Thread 523: finished !!!
# Thread 526: getting 42 links ...
# Thread 518: finished !!!
# Thread 527: getting 42 links ...
# Thread 513: finished !!!
# Thread 528: getting 42 links ...
# Thread 526: finished !!!
# Thread 529: getting 41 links ...
# Thread 528: finished !!!
# Thread 530: getting 40 links ...
# Thread 522: finished !!!
# Thread 531: getting 40 links ...
# Thread 531: finished !!!
# Thread 532: getting 40 links ...
# Thread 527: finished !!!
# Thread 533: getting 39 links ...
# Thread 520: finished !!!
# Thread 534: getting 38 links ...
# Thread 524: finished !!!
# Thread 535: getting 38 links ...
# Thread 519: finished !!!
# Thread 536: getting 38 links ...
# Thread 525: finished !!!
# Thread 537: getting 38 links ...
# Thread 536: finished !!!
# Thread 538: getting 38 links ...
# Thread 535: finished !!!
# Thread 539: getting 37 links ...
# Thread 529: finished !!!
# Thread 540: getting 37 links ...
# Thread 534: finished !!!
# Thread 541: getting 37 links ...
# Thread 533: finished !!!
# Thread 542: getting 37 links ...
# Thread 540: finished !!!
# Thread 543: getting 37 links ...
# Thread 538: finished !!!
# Thread 544: getting 35 links ...
# Thread 537: finished !!!
# Thread 545: getting 35 links ...
# Thread 532: finished !!!
# Thread 546: getting 34 links ...
# Thread 543: finished !!!
# Thread 547: getting 34 links ...
# Thread 545: finished !!!
# Thread 548: getting 34 links ...
# Thread 541: finished !!!
# Thread 549: getting 33 links ...
# Thread 530: finished !!!
# Thread 550: getting 32 links ...
# Thread 539: finished !!!
# Thread 551: getting 31 links ...
# Thread 547: finished !!!
# Thread 552: getting 31 links ...
# Thread 551: finished !!!
# Thread 553: getting 31 links ...
# Thread 550: finished !!!
# Thread 554: getting 30 links ...
# Thread 552: finished !!!
# Thread 555: getting 30 links ...
# Thread 549: finished !!!
# Thread 556: getting 30 links ...
# Thread 554: finished !!!
# Thread 557: getting 29 links ...
# Thread 553: finished !!!
# Thread 558: getting 29 links ...
# Thread 542: finished !!!
# Thread 559: getting 29 links ...
# Thread 558: finished !!!
# Thread 560: getting 28 links ...
# Thread 544: finished !!!
# Thread 561: getting 28 links ...
# Thread 560: finished !!!
# Thread 562: getting 26 links ...
# Thread 559: finished !!!
# Thread 563: getting 26 links ...
# Thread 556: finished !!!
# Thread 564: getting 25 links ...
# Thread 563: finished !!!
# Thread 565: getting 23 links ...
# Thread 557: finished !!!
# Thread 566: getting 23 links ...
# Thread 562: finished !!!
# Thread 567: getting 23 links ...
# Thread 565: finished !!!
# Thread 568: getting 23 links ...
# Thread 555: finished !!!
# Thread 569: getting 23 links ...
# Thread 564: finished !!!
# Thread 570: getting 23 links ...
# Thread 566: finished !!!
# Thread 571: getting 23 links ...
# Thread 567: finished !!!
# Thread 572: getting 23 links ...
# Thread 561: finished !!!
# Thread 573: getting 22 links ...
# Thread 569: finished !!!
# Thread 574: getting 21 links ...
# Thread 546: finished !!!
# Thread 575: getting 21 links ...
# Thread 571: finished !!!
# Thread 576: getting 21 links ...
# Thread 575: finished !!!
# Thread 577: getting 20 links ...
# Thread 570: finished !!!
# Thread 578: getting 19 links ...
# Thread 568: finished !!!
# Thread 579: getting 17 links ...
# Thread 574: finished !!!
# Thread 580: getting 17 links ...
# Thread 580: finished !!!
# Thread 581: getting 17 links ...
# Thread 579: finished !!!
# Thread 582: getting 17 links ...
# Thread 573: finished !!!
# Thread 583: getting 16 links ...
# Thread 577: finished !!!
# Thread 584: getting 16 links ...
# Thread 583: finished !!!
# Thread 585: getting 16 links ...
# Thread 576: finished !!!
# Thread 586: getting 16 links ...
# Thread 548: finished !!!
# Thread 587: getting 16 links ...
# Thread 584: finished !!!
# Thread 588: getting 16 links ...
# Thread 582: finished !!!
# Thread 589: getting 15 links ...
# Thread 588: finished !!!
# Thread 590: getting 15 links ...
# Thread 585: finished !!!
# Thread 591: getting 13 links ...
# Thread 587: finished !!!
# Thread 592: getting 13 links ...
# Thread 578: finished !!!
# Thread 593: getting 13 links ...
# Thread 591: finished !!!
# Thread 594: getting 12 links ...
# Thread 572: finished !!!
# Thread 595: getting 12 links ...
# Thread 590: finished !!!
# Thread 596: getting 12 links ...
# Thread 589: finished !!!
# Thread 597: getting 12 links ...
# Thread 593: finished !!!
# Thread 598: getting 12 links ...
# Thread 595: finished !!!
# Thread 599: getting 12 links ...
# Thread 586: finished !!!
# Thread 600: getting 11 links ...
# Thread 581: finished !!!
# Thread 601: getting 11 links ...
# Thread 596: finished !!!
# Thread 602: getting 11 links ...
# Thread 599: finished !!!
# Thread 603: getting 10 links ...
# Thread 602: finished !!!
# Thread 604: getting 10 links ...
# Thread 594: finished !!!
# Thread 605: getting 10 links ...
# Thread 592: finished !!!
# Thread 606: getting 10 links ...
# Thread 598: finished !!!
# Thread 607: getting 10 links ...
# Thread 604: finished !!!
# Thread 608: getting 10 links ...
# Thread 601: finished !!!
# Thread 609: getting 10 links ...
# Thread 603: finished !!!
# Thread 610: getting 10 links ...
# Thread 597: finished !!!
# Thread 611: getting 10 links ...
# Thread 605: finished !!!
# Thread 612: getting 10 links ...
# Thread 608: finished !!!
# Thread 613: getting 10 links ...
# Thread 600: finished !!!
# Thread 614: getting 10 links ...
# Thread 609: finished !!!
# Thread 615: getting 10 links ...
# Thread 613: finished !!!
# Thread 616: getting 10 links ...
# Thread 614: finished !!!
# Thread 617: getting 10 links ...
# Thread 610: finished !!!
# Thread 618: getting 10 links ...
# Thread 615: finished !!!
# Thread 619: getting 10 links ...
# Thread 617: finished !!!
# Thread 620: getting 10 links ...
# Thread 611: finished !!!
# Thread 621: getting 10 links ...
# Thread 616: finished !!!
# Thread 622: getting 9 links ...
# Thread 619: finished !!!
# Thread 623: getting 9 links ...
# Thread 607: finished !!!
# Thread 624: getting 9 links ...
# Thread 621: finished !!!
# Thread 625: getting 9 links ...
# Thread 623: finished !!!
# Thread 626: getting 9 links ...
# Thread 612: finished !!!
# Thread 627: getting 9 links ...
# Thread 625: finished !!!
# Thread 628: getting 9 links ...
# Thread 606: finished !!!
# Thread 629: getting 9 links ...
# Thread 627: finished !!!
# Thread 630: getting 8 links ...
# Thread 628: finished !!!
# Thread 631: getting 8 links ...
# Thread 620: finished !!!
# Thread 632: getting 8 links ...
# Thread 624: finished !!!
# Thread 633: getting 8 links ...
# Thread 622: finished !!!
# Thread 634: getting 8 links ...
# Thread 626: finished !!!
# Thread 635: getting 8 links ...
# Thread 618: finished !!!
# Thread 636: getting 8 links ...
# Thread 629: finished !!!
# Thread 637: getting 8 links ...
# Thread 634: finished !!!
# Thread 638: getting 7 links ...
# Thread 630: finished !!!
# Thread 639: getting 6 links ...
# Thread 632: finished !!!
# Thread 640: getting 6 links ...
# Thread 637: finished !!!
# Thread 641: getting 6 links ...
# Thread 639: finished !!!
# Thread 642: getting 6 links ...
# Thread 642: finished !!!
# Thread 643: getting 6 links ...
# Thread 638: finished !!!
# Thread 644: getting 6 links ...
# Thread 644: finished !!!
# Thread 645: getting 6 links ...
# Thread 641: finished !!!
# Thread 646: getting 6 links ...
# Thread 633: finished !!!
# Thread 647: getting 6 links ...
# Thread 631: finished !!!
# Thread 648: getting 6 links ...
# Thread 645: finished !!!
# Thread 649: getting 6 links ...
# Thread 635: finished !!!
# Thread 650: getting 6 links ...
# Thread 640: finished !!!
# Thread 651: getting 6 links ...
# Thread 648: finished !!!
# Thread 652: getting 6 links ...
# Thread 651: finished !!!
# Thread 653: getting 6 links ...
# Thread 636: finished !!!
# Thread 654: getting 5 links ...
# Thread 647: finished !!!
# Thread 655: getting 5 links ...
# Thread 655: finished !!!
# Thread 656: getting 5 links ...
# Thread 653: finished !!!
# Thread 657: getting 5 links ...
# Thread 656: finished !!!
# Thread 658: getting 5 links ...
# Thread 650: finished !!!
# Thread 659: getting 5 links ...
# Thread 646: finished !!!
# Thread 660: getting 5 links ...
# Thread 643: finished !!!
# Thread 661: getting 5 links ...
# Thread 654: finished !!!
# Thread 662: getting 5 links ...
# Thread 659: finished !!!
# Thread 663: getting 5 links ...
# Thread 662: finished !!!
# Thread 664: getting 5 links ...
# Thread 652: finished !!!
# Thread 665: getting 4 links ...
# Thread 663: finished !!!
# Thread 666: getting 4 links ...
# Thread 661: finished !!!
# Thread 667: getting 4 links ...
# Thread 665: finished !!!
# Thread 668: getting 4 links ...
# Thread 658: finished !!!
# Thread 669: getting 4 links ...
# Thread 667: finished !!!
# Thread 670: getting 4 links ...
# Thread 669: finished !!!
# Thread 671: getting 4 links ...
# Thread 649: finished !!!
# Thread 672: getting 4 links ...
# Thread 668: finished !!!
# Thread 673: getting 4 links ...
# Thread 672: finished !!!
# Thread 674: getting 4 links ...
# Thread 657: finished !!!
# Thread 675: getting 4 links ...
# Thread 675: finished !!!
# Thread 676: getting 4 links ...
# Thread 670: finished !!!
# Thread 677: getting 4 links ...
# Thread 674: finished !!!
# Thread 678: getting 4 links ...
# Thread 677: finished !!!
# Thread 679: getting 4 links ...
# Thread 673: finished !!!
# Thread 680: getting 3 links ...
# Thread 666: finished !!!
# Thread 681: getting 3 links ...
# Thread 678: finished !!!
# Thread 682: getting 3 links ...
# Thread 664: finished !!!
# Thread 683: getting 3 links ...
# Thread 681: finished !!!
# Thread 684: getting 3 links ...
# Thread 680: finished !!!
# Thread 685: getting 3 links ...
# Thread 671: finished !!!
# Thread 686: getting 3 links ...
# Thread 685: finished !!!
# Thread 687: getting 3 links ...
# Thread 676: finished !!!
# Thread 688: getting 3 links ...
# Thread 682: finished !!!
# Thread 689: getting 3 links ...
# Thread 683: finished !!!
# Thread 690: getting 3 links ...
# Thread 679: finished !!!
# Thread 691: getting 3 links ...
# Thread 690: finished !!!
# Thread 692: getting 3 links ...
# Thread 684: finished !!!
# Thread 693: getting 3 links ...
# Thread 691: finished !!!
# Thread 694: getting 3 links ...
# Thread 687: finished !!!
# Thread 695: getting 3 links ...
# Thread 693: finished !!!
# Thread 696: getting 2 links ...
# Thread 660: finished !!!
# Thread 697: getting 2 links ...
# Thread 692: finished !!!
# Thread 698: getting 2 links ...
# Thread 696: finished !!!
# Thread 699: getting 2 links ...
# Thread 688: finished !!!
# Thread 700: getting 2 links ...
# Thread 695: finished !!!
# Thread 701: getting 2 links ...
# Thread 686: finished !!!
# Thread 702: getting 2 links ...
# Thread 701: finished !!!
# Thread 703: getting 2 links ...
# Thread 697: finished !!!
# Thread 704: getting 2 links ...
# Thread 703: finished !!!
# Thread 705: getting 2 links ...
# Thread 699: finished !!!
# Thread 706: getting 2 links ...
# Thread 705: finished !!!
# Thread 707: getting 2 links ...
# Thread 700: finished !!!
# Thread 708: getting 2 links ...
# Thread 694: finished !!!
# Thread 709: getting 2 links ...
# Thread 706: finished !!!
# Thread 710: getting 2 links ...
# Thread 704: finished !!!
# Thread 711: getting 2 links ...
# Thread 709: finished !!!
# Thread 712: getting 2 links ...
# Thread 698: finished !!!
# Thread 713: getting 2 links ...
# Thread 707: finished !!!
# Thread 714: getting 2 links ...
# Thread 708: finished !!!
# Thread 715: getting 2 links ...
# Thread 711: finished !!!
# Thread 716: getting 2 links ...
# Thread 712: finished !!!
# Thread 717: getting 2 links ...
# Thread 710: finished !!!
# Thread 718: getting 2 links ...
# Thread 702: finished !!!
# Thread 719: getting 2 links ...
# Thread 717: finished !!!
# Thread 720: getting 2 links ...
# Thread 719: finished !!!
# Thread 721: getting 2 links ...
# Thread 718: finished !!!
# Thread 722: getting 1 links ...
# Thread 722: finished !!!
# Thread 723: getting 1 links ...
# Thread 716: finished !!!
# Thread 724: getting 1 links ...
# Thread 714: finished !!!
# Thread 725: getting 1 links ...
# Thread 723: finished !!!
# Thread 726: getting 1 links ...
# Thread 689: finished !!!
# Thread 727: getting 1 links ...
# Thread 713: finished !!!
# Thread 728: getting 1 links ...
# Thread 720: finished !!!
# Thread 729: getting 1 links ...
# Thread 727: finished !!!
# Thread 730: getting 1 links ...
# Thread 728: finished !!!
# Thread 731: getting 1 links ...
# Thread 725: finished !!!
# Thread 732: getting 1 links ...
# Thread 721: finished !!!
# Thread 733: getting 1 links ...
# Thread 726: finished !!!
# Thread 734: getting 1 links ...
# Thread 731: finished !!!
# Thread 735: getting 1 links ...
# Thread 733: finished !!!
# Thread 736: getting 1 links ...
# Thread 730: finished !!!
# Thread 737: getting 1 links ...
# Thread 715: finished !!!
# Thread 738: getting 1 links ...
# Thread 732: finished !!!
# Thread 739: getting 1 links ...
# Thread 735: finished !!!
# Thread 740: getting 1 links ...
# Thread 737: finished !!!
# Thread 741: getting 1 links ...
# Thread 736: finished !!!
# Thread 742: getting 1 links ...
# Thread 729: finished !!!
# Thread 743: getting 1 links ...
# Thread 734: finished !!!
# Thread 744: getting 1 links ...
# Thread 739: finished !!!
# Thread 745: getting 1 links ...
# Thread 740: finished !!!
# Thread 746: getting 1 links ...
# Thread 742: finished !!!
# Thread 747: getting 1 links ...
# Thread 741: finished !!!
# Thread 748: getting 1 links ...
# Thread 744: finished !!!
# Thread 749: getting 1 links ...
# Thread 724: finished !!!
# Thread 750: getting 1 links ...
# Thread 748: finished !!!
# Thread 751: getting 1 links ...
# Thread 746: finished !!!
# Thread 752: getting 1 links ...
# Thread 743: finished !!!
# Thread 753: getting 1 links ...
# Thread 749: finished !!!
# Thread 754: getting 1 links ...
# Thread 745: finished !!!
# Thread 755: getting 1 links ...
# Thread 751: finished !!!
# Thread 756: getting 1 links ...
# Thread 753: finished !!!
# Thread 757: getting 1 links ...
# Thread 756: finished !!!
# Thread 758: getting 1 links ...
# Thread 754: finished !!!
# Thread 759: getting 1 links ...
# Thread 752: finished !!!
# Thread 760: getting 1 links ...
# Thread 758: finished !!!
# Thread 761: getting 1 links ...
# Thread 755: finished !!!
# Thread 762: getting 1 links ...
# Thread 760: finished !!!
# Thread 763: getting 1 links ...
# Thread 762: finished !!!
# Thread 764: getting 1 links ...
# Thread 759: finished !!!
# Thread 765: getting 1 links ...
# Thread 763: finished !!!
# Thread 766: getting 1 links ...
# Thread 764: finished !!!
# Thread 767: getting 1 links ...
# Thread 765: finished !!!
# Thread 768: getting 1 links ...
# Thread 766: finished !!!
# Thread 769: getting 1 links ...
# Thread 768: finished !!!
# Thread 770: getting 1 links ...
# Thread 767: finished !!!
# Thread 771: getting 1 links ...
# Thread 769: finished !!!
# Thread 772: getting 1 links ...
# Thread 747: finished !!!
# Thread 773: getting 1 links ...
# Thread 772: finished !!!
# Thread 774: getting 1 links ...
# Thread 773: finished !!!
# Thread 750: finished !!!
# Thread 774: finished !!!
# Thread 738: finished !!!
# Thread 761: finished !!!
# Thread 771: finished !!!
# Thread 770: finished !!!
# Thread 757: finished !!!
# !!!!!! Finished Scraping Links !!!!!!
# for-rent data len: 76306
# for-sale data len: 37092
