# %% [markdown]
# ## PropertyHub: 5.2 Geocoding

# %%
# First let's set up the environment for Selenium to work in Kaggle
# install google chrome
# !wget https://dl.google.com/linux/linux_signing_key.pub &>/dev/null 2>&1
# !sudo apt-key add linux_signing_key.pub &>/dev/null 2>&1
# !echo 'deb [arch=amd64] http://dl.google.com/linux/chrome/deb/ stable main' >> /etc/apt/sources.list.d/google-chrome.list;
# !sudo apt-get -y update &>/dev/null 2>&1
# !sudo apt-get install -y google-chrome-stable &>/dev/null 2>&1

# install chromedriver
# !apt-get install -y qq unzip
# !wget -O /tmp/chromedriver.zip http://chromedriver.storage.googleapis.com/`curl -sS chromedriver.storage.googleapis.com/LATEST_RELEASE`/chromedriver_linux64.zip >/dev/null 2>&1
# !unzip /tmp/chromedriver.zip chromedriver -d /usr/local/bin/ &>/dev/null 2>&1

# install selenium
# !sudo apt install -y python3-selenium &>/dev/null 2>&1
# !pip install selenium &>/dev/null 2>&1

import os
# Delete unused files
file = 'linux_signing_key.pub'
path = '/kaggle/working/'+file

if os.path.isfile(path):
    os.remove(path)
    
# To check Google Chrome's version
# !google-chrome --version;

# To check Chrome Driver's version
# !chromedriver -v;
# Out:
# curl: /opt/conda/lib/libcurl.so.4: no version information available (required by curl)
# Google Chrome 114.0.5735.198
# ChromeDriver 114.0.5735.90 (386bc09e8f4f2e025eddae123f36f6263096ae49-refs/branch-heads/5735@{#1052})

# %%
# Import libraries
import pandas as pd
import numpy as np
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

# %%
class Geocode():
    def __init__(self):
        self.date = '202306'
        
        self.gg_map_url = 'https://www.google.co.th/maps'
        self.adj_place = 'Nye by Sansiri, Krung Thon Buri'
        self.lat_adj_place = 13.721834732432393
        self.lon_adj_place = 100.4979593259578
        self.adj_place_2 = '107 Baring Condo, Muang Samut Prakarn Samut Prakarn'
        self.lat_adj_place_2 = 13.65613877106645
        self.lon_adj_place_2 = 100.6063992928716
        
        self.lat_min = 5
        self.lon_min = 96
        self.lat_max = 22
        self.lon_max = 106
        self.lat = []
        self.lon = []
        self.gg_address = []
        self.gg_address_temp = ''
        self.error_index = []
        self.done_count = 0
        self.delay_time = 1
        self.timeout_while = 20
        
    def import_data(self):
        path = '/kaggle/input/ph-4-data-engineering'
        file_names = f"{self.date}_project.csv"
        self.project = pd.read_csv(f'{path}/{file_names}')
        half_project_len = round(len(self.project)/2)
        self.project = self.project.iloc[half_project_len:,:]
        self.project.reset_index(drop=True, inplace=True)
        print(f'Data imported Project: {len(self.project)} records')
        
    def driver_setup(self):
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument('--no-sandbox')
        chrome_options.add_argument('--headless')
        chrome_options.add_argument('--disable-gpu')
        chrome_options.add_argument('--disable-dev-shm-usage')
        chrome_options.add_argument("--window-size=1920,1080")
        self.driver = webdriver.Chrome(options=chrome_options)
        self.action = ActionChains(self.driver)
        print(f'Web driver is set up')
    
    def find_adj(self):
        self.driver.get(self.gg_map_url)
        self.driver.implicitly_wait(5)
        time.sleep(2)
        text_box = self.driver.find_elements(by=By.XPATH, value='//input[contains(@id,"searchboxinput")]')
        search_button = self.driver.find_elements(by=By.XPATH, value='//button[contains(@id,"searchbox-searchbutton")]')
        text_box[0].send_keys(self.adj_place)
        self.action.click(on_element = search_button[0])
        self.action.perform()
        
        url = self.driver.current_url
        timeout = time.time() + self.timeout_while
        while url == self.gg_map_url:
            url = self.driver.current_url
            if time.time() > timeout:
                break
            
        count_at = url.count('@')
        if count_at >= 2:
            for _ in range(count_at-1):
                url = url[url.find('@')+1:]
        
        find_at = url[url.find('@'):]
        lat = float(find_at[1:find_at.find(',')])
        lon = float(find_at[find_at.find(',')+1:find_at.find(',',find_at.find(',')+2)])
        
        self.lat_adj = self.lat_adj_place-lat
        self.lon_adj = self.lon_adj_place-lon
        time.sleep(3)
        print(f'1st lat and lon adjustments are calculated')
    
    def find_adj2(self):
        self.driver.get(self.gg_map_url)
        self.driver.implicitly_wait(5)
        time.sleep(2)
        text_box = self.driver.find_elements(by=By.XPATH, value='//input[contains(@id,"searchboxinput")]')
        search_button = self.driver.find_elements(by=By.XPATH, value='//button[contains(@id,"searchbox-searchbutton")]')
        text_box[0].send_keys(self.adj_place_2)
        self.action.click(on_element = search_button[0])
        self.action.perform()
        
        url = self.driver.current_url
        while url == self.gg_map_url:
            url = self.driver.current_url
        
        time.sleep(3)
        link = self.driver.find_elements(by=By.XPATH, value='//a[contains(@class,"hfpxzc")]')[0].get_attribute('href')
        self.driver.get(link)
        self.driver.implicitly_wait(5)

        url = self.driver.current_url
        at_count = url.count('@')
        timeout = time.time() + self.timeout_while
        while url.count('@') < (at_count+1):
            url = self.driver.current_url
            if time.time() > timeout:
                break

        try:
            self.driver.find_elements(by=By.XPATH, value='//button[contains(@data-item-id,"address")]')[0].text
        except:
            print(f'Cannot find address {self.adj_place_2}')
            return 0,0
            
        count_at = url.count('@')
        if count_at >= 2:
            for _ in range(count_at-1):
                url = url[url.find('@')+1:]
        
        find_at = url[url.find('@'):]
        lat = float(find_at[1:find_at.find(',')])
        lon = float(find_at[find_at.find(',')+1:find_at.find(',',find_at.find(',')+2)])
        
        self.lat_adj_2 = self.lat_adj_place_2-lat
        self.lon_adj_2 = self.lon_adj_place_2-lon
        time.sleep(3)
        print(f'2nd lat and lon adjustments are calculated')
        
    def find_lat_lon(self, place):
        self.driver.get(self.gg_map_url)
        self.driver.implicitly_wait(5)
        time.sleep(1)
        text_box = self.driver.find_elements(by=By.XPATH, value='//input[contains(@id,"searchboxinput")]')
        search_button = self.driver.find_elements(by=By.XPATH, value='//button[contains(@id,"searchbox-searchbutton")]')
        text_box[0].send_keys(place.replace('.',''))
        self.action.click(on_element = search_button[0])
        self.action.perform()
        
        url = self.driver.current_url
        timeout = time.time() + self.timeout_while
        while url == self.gg_map_url:
            url = self.driver.current_url
            if time.time() > timeout:
                break
        
        adj_2_flag = 0
        try:
            self.gg_address_temp = self.driver.find_elements(by=By.XPATH, value='//button[contains(@data-item-id,"address")]')[0].text
        except:
            try: 
                time.sleep(0.5)
                link = self.driver.find_elements(by=By.XPATH, value='//a[contains(@class,"hfpxzc")]')[0].get_attribute('href')
                self.driver.get(link)
                self.driver.implicitly_wait(5)
                
                url = self.driver.current_url
                at_count = url.count('@')
                timeout = time.time() + self.timeout_while
                while url.count('@') < (at_count+1):
                    url = self.driver.current_url
                    if time.time() > timeout:
                        break
                
                try:
                    self.gg_address_temp = self.driver.find_elements(by=By.XPATH, value='//button[contains(@data-item-id,"address")]')[0].text
                    adj_2_flag = 1
                except:
                    time.sleep(self.delay_time)
                    return 0,0
            except:
                time.sleep(self.delay_time)
                return 0,0
                
        url = self.driver.current_url
        count_at = url.count('@')
        if count_at >= 2:
            for _ in range(count_at-1):
                url = url[url.find('@')+1:]
        
        find_at = url[url.find('@'):]
        lat_temp = float(find_at[1:find_at.find(',')])
        lon_temp = float(find_at[find_at.find(',')+1:find_at.find(',',find_at.find(',')+2)])
        lat_temp = lat_temp + self.lat_adj if adj_2_flag == 0 else lat_temp + self.lat_adj_2
        lon_temp = lon_temp + self.lon_adj if adj_2_flag == 0 else lon_temp + self.lon_adj_2
        time.sleep(self.delay_time)
        return lat_temp, lon_temp
        
    def find_geocode(self):
        print(f'Start scraping geocodes ...')
        print('---'*10)
        for i in range(len(self.project)):
            place = self.project.loc[i,'project_name'] + ', ' + self.project.loc[i,'address']
            lat_temp, lon_temp = self.find_lat_lon(place)
            if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                place = self.project.loc[i,'project_name'] + ', ' + self.project.loc[i,'address'].split()[-1]
                lat_temp, lon_temp = self.find_lat_lon(place)
                if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                    place = self.project.loc[i,'project_name']
                    lat_temp, lon_temp = self.find_lat_lon(place)
                    if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                        place = self.project.loc[i,'project_name'] + ' Condo, '
                        lat_temp, lon_temp = self.find_lat_lon(place)
                        if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                            place = self.project.loc[i,'project_name'] + ' Condo' + self.project.loc[i,'address']
                            lat_temp, lon_temp = self.find_lat_lon(place)
                            if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                                place = self.project.loc[i,'project_name'] + ' Condo, ' + self.project.loc[i,'address'].split()[-1]
                                lat_temp, lon_temp = self.find_lat_lon(place)
                                if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                                    place = ' '.join(self.project.loc[i,'project_name'].split()[:-1]) + ' Condo, ' + self.project.loc[i,'address']
                                    lat_temp, lon_temp = self.find_lat_lon(place)
                                    if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                                        place = ' '.join(self.project.loc[i,'project_name'].split()[:-1]) + ' Condo, ' + self.project.loc[i,'address'].split()[-1]
                                        lat_temp, lon_temp = self.find_lat_lon(place)
                                        if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                                            place = self.project.loc[i,'project_name'] + ' Condo, ' + self.project.loc[i,'address']
                                            print(f'Error getting lat,lon at {i}: ({lat_temp},{lon_temp}) {place}')
                                            self.error_index.append(i)
                                            lat_temp = np.nan
                                            lon_temp = np.nan
                                            self.gg_address_temp = ''
            
            self.lat.append(lat_temp)
            self.lon.append(lon_temp)
            self.gg_address.append(self.gg_address_temp)
            
            print(f'Done {self.done_count}: ({lat_temp},{lon_temp}) {place}')
            self.done_count += 1
            
    def concat_df(self):
        self.project['lat'] = self.lat
        self.project['lon'] = self.lon
        self.project['gg_address'] = self.gg_address
        
    def find_geocode_again_for_na(self):
        self.project_na = self.project[self.project['lat'].isna()]
        for i in self.project_na.index:
            place = self.project.loc[i,'project_name'] + ', ' + self.project.loc[i,'address']
            lat_temp, lon_temp = self.find_lat_lon(place)
            if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                place = self.project.loc[i,'project_name'] + ', ' + self.project.loc[i,'address'].split()[-1]
                lat_temp, lon_temp = self.find_lat_lon(place)
                if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                    place = self.project.loc[i,'project_name']
                    lat_temp, lon_temp = self.find_lat_lon(place)
                    if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                        place = self.project.loc[i,'project_name'] + ' Condo, '
                        lat_temp, lon_temp = self.find_lat_lon(place)
                        if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                            place = self.project.loc[i,'project_name'] + ' Condo' + self.project.loc[i,'address']
                            lat_temp, lon_temp = self.find_lat_lon(place)
                            if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                                place = self.project.loc[i,'project_name'] + ' Condo, ' + self.project.loc[i,'address'].split()[-1]
                                lat_temp, lon_temp = self.find_lat_lon(place)
                                if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                                    place = ' '.join(self.project.loc[i,'project_name'].split()[:-1]) + ' Condo, ' + self.project.loc[i,'address']
                                    lat_temp, lon_temp = self.find_lat_lon(place)
                                    if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                                        place = ' '.join(self.project.loc[i,'project_name'].split()[:-1]) + ' Condo, ' + self.project.loc[i,'address'].split()[-1]
                                        lat_temp, lon_temp = self.find_lat_lon(place)
                                        if (lat_temp < self.lat_min) or (lat_temp > self.lat_max) or (lon_temp < self.lon_min) or (lon_temp > self.lon_max):
                                            place = self.project.loc[i,'project_name'] + ', ' + self.project.loc[i,'address']
                                            print(f'Still error getting lat,lon at {i}: ({lat_temp},{lon_temp}) {place}')
                                            lat_temp = np.nan
                                            lon_temp = np.nan
                                            self.gg_address_temp = ''
            
            self.project.loc[i,'lat'] = lat_temp
            self.project.loc[i,'lon'] = lon_temp
            self.project.loc[i,'gg_address'] = self.gg_address_temp
            
    def export_results(self):
        self.project.to_csv(f"{self.date}_project_geo_2.csv",index=False)
        print('---'*10)
        print('Results exported')
        
    def main(self):
        self.import_data()
        self.driver_setup()
        self.find_adj()
        self.find_adj2()
        self.find_geocode()
        self.concat_df()
        self.find_geocode_again_for_na()
        self.export_results()
        self.driver.quit()

# %%
GC = Geocode()
GC.main()
# Out:
# Data imported Project: 1664 records
# Web driver is set up
# 1st lat and lon adjustments are calculated
# 2nd lat and lon adjustments are calculated
# Start scraping geocodes ...
# ------------------------------
# Done 0: (13.799890732432392,100.5735267259578) Pano Ville, Din Daeng Bangkok
# Done 1: (18.799913632432393,98.9732634259578) Pansook The Urban Condo, Muang Chiang Mai Chiang Mai
# Done 2: (13.240654371066451,100.9490403928716) Panya Resort Condominium, Muang Chon Buri Chonburi
# Done 3: (7.882723671066451,98.2758561928716) Paradise Beach Residence, Kathu Phuket
# Done 4: (13.010512732432392,100.9281552259578) Paradise Ocean View, Bang Lamung Chonburi
# Done 5: (12.887696832432393,100.8862585259578) Paradise Park Jomtien Resort, Bang Lamung Chonburi
# Done 6: (18.764841732432394,99.0351385259578) Parano Condo @ Chiangmai, Muang Chiang Mai Chiang Mai
# Done 7: (13.81173667106645,100.6671855928716) Parc Exo Kaset - Navamintra, Bueng Kum Bangkok
# Done 8: (13.889092032432393,100.5987044259578) Parc Residence @ Phahol, Bang Khen Bangkok
# Done 9: (13.72508017106645,100.5656896928716) Park 24, Khlong Toei Bangkok
# Done 10: (12.967065271066451,100.8846884928716) Park Beach, Bang Lamung Chonburi
# Done 11: (14.98074117106645,103.0741609928716) Park Condo Dream Buri Ram, Muang Buri Ram Buri Ram
# Done 12: (14.00697487106645,99.54370889287159) Park Condo Dream Kanchanaburi, Muang Kanchanaburi Kanchanaburi
# Done 13: (16.721870332432395,98.58360982595781) Park Condo Dream Maesot, Mae Sod Tak
# Done 14: (14.955713832432393,102.0302626259578) Park Condo Dream Nakhon Ratchasima, Muang Nakhon Ratchasima Nakhon Ratchasima
# Done 15: (15.704994332432392,100.1197126259578) Park Condo Dream Nakhonsawan, Muang Nakhon Sawan Nakhon Sawan
# Done 16: (13.898568932432392,101.5766362259578) Park Condo Dream Prachinburi, Sri Maha Pho Prachinburi
# Done 17: (13.714490532432393,100.6033157259578) Park Court Sukhumvit 77, Watthana Bangkok
# Done 18: (12.88970317106645,100.8876067928716) Park Lane Resort, Bang Lamung Chonburi
# Done 19: (13.747182232432392,100.5516055259578) Park Ploenchit, Watthana Bangkok
# Done 20: (13.853241532432392,100.6362717259578) Park Ramindra, Bang Khen Bangkok
# Done 21: (12.919025232432393,100.8694958259578) Park Royal 2, Bang Lamung Chonburi
# Done 22: (12.910962032432392,100.8629460259578) Park Royal 3, Bang Lamung Chonburi
# Done 23: (13.288921232432392,100.9314678259578) Park Siri Condo Resort Bangsaen, Muang Chon Buri Chonburi
# Done 24: (13.89149997106645,100.5841335928716) Park View  Vibhavadi Condo,
# Done 25: (13.720619832432392,100.6811330259578) Park Village Onnut - Suvarnabhumi, Prawet Bangkok
# Done 26: (13.646932132432392,100.4950039259578) Parque Phutthabucha 48, Thung Khru Bangkok
# Done 27: (13.687695032432392,100.3763732259578) Patchara Place, Nong Khaem Bangkok
# Done 28: (13.748358132432392,100.5272969259578) Pathumwan Oasis, Pathum Wan Bangkok
# Done 29: (13.748694932432393,100.5304084259578) Pathumwan Place, Bangkok
# Done 30: (13.754611332432393,100.5344973259578) Pathumwan Resort Condo,
# Done 31: (7.877451432432393,98.2987386259578) Patong Bay Hill Phase 2, Kathu Phuket
# Done 32: (7.906631471066451,98.3051282928716) Patong Bay Seaview Residence, 23 Kathu Phuket
# Done 33: (7.900240332432393,98.3023138259578) Patong Grand Condotel, Kathu Phuket
# Done 34: (7.902148132432393,98.3081823259578) Patong Loft Condominium, Kathu Phuket
# Done 35: (7.891601032432392,98.2956183259578) Patong Tower condominium, Kathu Phuket
# Done 36: (13.765448632432392,100.5410114259578) Pattanachat Place, Phaya Thai Bangkok
# Done 37: (13.73842737106645,100.6179524928716) Pattanakarn Life Complex, Suan Luang Bangkok
# Done 38: (13.59336567106645,100.8294043928716) Pattarapa Place, Prakarn
# Done 39: (12.939041232432393,100.8720540259578) Pattaya Beach, Bang Lamung Chonburi
# Done 40: (12.928859971066451,100.8786841928716) Pattaya City Resort, Bang Lamung Chonburi
# Done 41: (12.873779132432393,100.89142252595781) Pattaya Condotel Chain, Bang Lamung Chonburi
# Done 42: (13.008888432432393,100.9283273259578) Pattaya Del Rey, Bang Lamung Chonburi
# Done 43: (12.918757432432393,100.8696053259578) Pattaya Heights, Bang Lamung Chonburi
# Done 44: (12.917423171066451,100.8658004928716) Pattaya Hill Resort, Bang Lamung Chonburi
# Done 45: (12.964383332432392,100.9223970259578) Pattaya Housing Authority, Bang Lamung Chonburi
# Done 46: (12.938308632432392,100.89424012595781) Pattaya Klang Center Point, Bang Lamung Chonburi
# Done 47: (12.929136232432393,100.9025296259578) Pattaya Plaza Condotel, Bang Lamung Chonburi
# Done 48: (12.949884132432393,100.9020391259578) Pattaya Posh, Bang Lamung Chonburi
# Done 49: (12.94473037106645,100.8863981928716) Pattaya tower, Bang Lamung Chonburi
# Done 50: (13.655070732432392,100.6074574259578) Pause ID, Muang Samut Prakarn Samut Prakarn
# Done 51: (13.657989032432393,100.6051093259578) Pause Sukhumvit 107, Muang Samut Prakarn Samut Prakarn
# Done 52: (13.636512632432392,100.5945759259578) Pause Sukhumvit 115, Muang Samut Prakarn Samut Prakarn
# Done 53: (12.921111632432392,100.8620050259578) Peak Condominium, Bang Lamung Chonburi
# Done 54: (13.724052571066451,100.5328318928716) Pearl Garden Condo,
# Done 55: (13.727767032432393,100.5666348259578) Pearl Residences Sukhumvit 24, Khlong Toei Bangkok
# Done 56: (13.713282732432393,100.4716625259578) Pela Wutthakat, Thon Buri Bangkok
# Done 57: (13.19140247106645,100.9338523928716) Penroong Condo View, Si Racha Chonburi
# Done 58: (13.832527232432392,100.5738964259578) Pensiri Place, Bangkok
# Done 59: (13.722957932432392,100.5882272259578) Penthouse Condominium 2, Watthana Bangkok
# Done 60: (13.720922032432393,100.5885377259578) Penthouse Condominium 3, Watthana Bangkok
# Done 61: (13.753343332432392,100.53413792595781) Petch 9 Tower, Ratchathewi Bangkok
# Done 62: (13.786612132432392,100.5483099259578) Phahol Metro
# Done 63: (13.786379332432393,100.5539493259578) Phahonyothin Park Condominium, Bangkok
# Done 64: (7.893003171066451,98.3017029928716) Phanason City Condominium, Muang Phuket Phuket
# Done 65: (13.77787097106645,100.5383810928716) Phasuk Place, Bangkok
# Done 66: (13.744753671066452,100.5675906928716) Phatphairin Condotown, Khlong Sam Wa Bangkok
# Done 67: (13.726574932432392,100.5882735259578) Phatsana Garden, Watthana Bangkok
# Done 68: (13.73309407106645,100.6382984928716) Phattara Sripat Tower, Suan Luang Bangkok
# Done 69: (13.71390457106645,100.4857989928716) Phayapirom Regent Taksin-Sathorn, Thon Buri Bangkok
# Done 70: (13.75845817106645,100.5339690928716) Phayathai Place Condo,
# Done 71: (13.756222671066451,100.5327433928716) Phayathai Plaza Condo,
# Done 72: (13.732440032432393,100.5721933259578) Phirom Garden Residence, Watthana Bangkok
# Done 73: (7.889045232432393,98.3899739259578) Phuket Avenue Condo, Muang Phuket Phuket
# Done 74: (8.00916587106645,98.3415340928716) Phuket Housing (Thalang), Thalang Phuket
# Done 75: (7.880091371066451,98.2930934928716) Phuket Palace, Kathu Phuket
# Done 76: (7.893002032432393,98.3017043259578) Phuket Villa Patong Beach, Kathu Phuket
# Done 77: (12.629472032432393,101.5539585259578) Phuphatara Rayong, Klaeng Rayong
# Done 78: (13.836388132432392,100.5742795259578) Phyll Phahol 34, Chatuchak Bangkok
# Done 79: (13.911413471066451,100.5024800928716) Pi Condominium, Pak Kret Nonthaburi
# Done 80: (13.827386971066451,100.5352425928716) Piboon Condoville, Bang Sue Bangkok
# Done 81: (13.707709332432392,100.4800810259578) Piemrak Ratchadapisek-Thapra, Thon Buri Bangkok
# Done 82: (14.00193407106645,100.69376309287159) Pier 93, Thanyaburi Pathumthani
# Done 83: (13.719335632432392,100.5277379259578) Pikul Place, Sathon Bangkok
# Done 84: (18.77270133243239,98.9927859259578) Ping Condo The Center piece, Muang Chiang Mai Chiang Mai
# Done 85: (18.77311183243239,98.9927097259578) Ping plus Condo, Muang Chiang Mai Chiang Mai
# Done 86: (12.952635932432392,100.8830305259578) Pingpha, Bang Lamung Chonburi
# Done 87: (13.781646732432392,100.4683144259578) Pinklao River Park View, Bang Phlat Bangkok
# Done 88: (13.784270232432393,100.4761876259578) Pinkrao Pavilion, Bang Phlat Bangkok
# Done 89: (13.723925732432393,100.5327411259578) Pipat Place, Bangkok
# Done 90: (13.820333832432393,100.5707024259578) Pisawit Tower, Chatuchak Bangkok
# Done 91: (13.726720932432393,100.5721779259578) Piya Residence, Khlong Toei Bangkok
# Done 92: (13.817995732432392,100.5830886259578) Piyaphirom, Chatuchak Bangkok
# Done 93: (7.964213571066451,98.2852142928716) Platinum Bay, Kathu Phuket
# Done 94: (13.01800957106645,101.1513245928716) Platinum Place Condo, Pluak Daeng Rayong
# Done 95: (13.01800957106645,101.1513245928716) Platinum Place Condo Eastern Seaboard, Pluak Daeng Rayong
# Done 96: (18.80155443243239,98.96552302595781) Play Condominium, Muang Chiang Mai Chiang Mai
# Done 97: (13.872806071066451,100.5065552928716) Ploen Ploen Bangbuathong - Westgate, Bang Bua Thong Nonthaburi
# Done 98: (13.872806071066451,100.5065552928716) Ploen Ploen Bangbuathong - Westgate 2, Bang Bua Thong Nonthaburi
# Done 99: (13.88867267106645,100.5209180928716) Ploen Ploen Chaengwattana - Pak Kret, Pak Kret Nonthaburi
# Done 100: (13.88867267106645,100.5209180928716) Ploen Ploen Pak Kret - Chaengwattana 2, Pak Kret Nonthaburi
# Done 101: (14.022641732432392,100.5327898259578) Ploen Ploen Plus Rangsit - Future Park, Thanyaburi Pathumthani
# Done 102: (13.872806071066451,100.5065552928716) Ploen Ploen Rama 5 - Ratchaphruek, Bang Kruai Nonthaburi
# Done 103: (13.872806071066451,100.5065552928716) Ploen Ploen Rama 7 - Bang Kruai 1, Bang Kruai Nonthaburi
# Done 104: (13.872806071066451,100.5065552928716) Ploen Ploen Rama 7 - Bang Kruai 2, Bang Kruai Nonthaburi
# Done 105: (13.999989771066451,100.5974352928716) Ploen Ploen Rangsit - Workpoint 1,2, Muang Pathum Thani Pathumthani
# Done 106: (14.02264287106645,100.5327884928716) Ploen Ploen Rangsit - Workpoint 3,4, Muang Pathum Thani Pathumthani
# Done 107: (13.990424071066451,100.5939017928716) Ploen Ploen Rangsit - Workpoint 5, Muang Pathum Thani Pathumthani
# Done 108: (13.804557971066451,100.4595926928716) Ploen Ploen Ratchaphruek - Pinklao 2, Bang Kruai Nonthaburi
# Done 109: (13.888671532432392,100.5209194259578) Ploen Ploen Samakee - Tiwanon, Pak Kret Nonthaburi
# Done 110: (13.872806071066451,100.5065552928716) Ploen Ploen Sanambinnam - Rattanathibet, Muang Nonthaburi Nonthaburi
# Done 111: (13.88867267106645,100.5209180928716) Ploen Ploen Tiwanon - Pakkred 2, Pak Kret Nonthaburi
# Done 112: (13.74543467106645,100.54982499287159) Ploenchit Terrace Condo,
# Done 113: (13.87923947106645,100.5858216928716) Plum Chaengwattana - Donmuang, Lak Si Bangkok
# Done 114: (13.710275432432393,100.3960473259578) Plum Condo Bangkae, Bang Khae Bangkok
# Done 115: (13.88940247106645,100.4059979928716) Plum Condo Bangyai Station, Bang Yai Nonthaburi
# Done 116: (13.875076132432392,100.4133861259578) Plum Condo Central Station, Bang Yai Nonthaburi
# Done 117: (13.875076132432392,100.4133861259578) Plum Condo Central Station Phase 2, Bang Yai Nonthaburi
# Done 118: (13.879561132432393,100.58585222595781) Plum Condo Chaengwattana Station, Lak Si Bangkok
# Done 119: (13.878709232432392,100.5865066259578) Plum Condo Chaengwattana Station Phase 2, Lak Si Bangkok
# Done 120: (13.879561132432393,100.58585222595781) Plum Condo Chaengwattana Station Phase 3, Lak Si Bangkok
# Done 121: (13.81292247106645,100.5960756928716) Plum Condo Chokchai 4, Lat Phrao Bangkok
# Done 122: (13.67213937106645,100.4595971928716) Plum Condo Extra Rama 2, Chom Thong Bangkok
# Done 123: (13.789053532432392,100.6277858259578) Plum Condo Ladprao 101, Bang Kapi Bangkok
# Done 124: (13.081809032432393,100.9240326259578) Plum Condo Laemchabang, Si Racha Chonburi
# Done 125: (13.88018577106645,100.5865114928716) Plum Condo Mix Chaengwattana, Lak Si Bangkok
# Done 126: (13.823757132432393,100.65861682595781) Plum Condo Nawamin, Bueng Kum Bangkok
# Done 127: (14.03101897106645,100.6106363928716) Plum Condo Park Rangsit, Khlong Luang Pathumthani
# Done 128: (13.97187077106645,100.6157815928716) Plum Condo Phaholyothin 89, Thanyaburi Pathumthani
# Done 129: (13.772278632432393,100.4833673259578) Plum Condo Pinklao Station, Bang Phlat Bangkok
# Done 130: (13.761205132432393,100.6490611259578) Plum Condo Ram 60 Interchange, Bang Kapi Bangkok
# Done 131: (13.743375632432393,100.6031923259578) Plum Condo Ramkhamhaeng Station, Suan Luang Bangkok
# Done 132: (14.030873471066451,100.6067057928716) Plum Condo Rangsit Alive, Khlong Luang Pathumthani
# Done 133: (13.883040832432393,100.5246019259578) Plum Condo Samakkhi, Muang Nonthaburi Nonthaburi
# Done 134: (13.894058532432393,100.6130201259578) Plum Condo Saphanmai Station, Sai Mai Bangkok
# Done 135: (13.693677932432392,100.6036461259578) Plum Condo Sukhumvit 62, Phra Khanong Bangkok
# Done 136: (13.69367907106645,100.6036447928716) Plum Condo Sukhumvit 97.1, Phra Khanong Bangkok
# Done 137: (13.67214607106645,100.4591621928716) Plum Rama 2, Chom Thong Bangkok
# Done 138: (13.721220132432393,100.5776798259578) Plus 38 Hip, Khlong Toei Bangkok
# Done 139: (13.718546932432393,100.5904975259578) Plus 67, Watthana Bangkok
# Done 140: (14.38370167106645,100.5923851928716) Plus Condo Ayutthaya, Uthai Phra Nakhon Sri Ayutthaya
# Done 141: (14.336497732432392,100.6124785259578) Plus Condo Ayutthaya Park, Phra Nakhon Sri Ayutthaya Phra Nakhon Sri Ayutthaya
# Done 142: (7.004385471066451,100.4612729928716) Plus Condo Hat Yai, Hat Yai Songkhla
# Done 143: (7.004384332432393,100.4612743259578) Plus Condo Hat Yai 2, Hat Yai Songkhla
# Done 144: (7.017697432432392,100.4829925259578) Plus Condo Hatyai 30 m., Hat Yai Songkhla
# Done 145: (14.980105632432393,102.0844588259578) Plus Condo Korat, Muang Nakhon Ratchasima Nakhon Ratchasima
# Done 146: (7.913180232432392,98.3311769259578) Plus Condo Phuket, Kathu Phuket
# Done 147: (7.913180232432392,98.3311769259578) Plus Condo Phuket 2, Kathu Phuket
# Done 148: (9.126554932432393,99.31224622595781) Plus Condo Suratthani, Muang Surat Thani Surat Thani
# Done 149: (13.16219807106645,100.9384594928716) Plus Sriracha, Si Racha Chonburi
# Done 150: (13.64971167106645,100.5134823928716) Polis Condo Suksawat 64, Phra Pra Daeng Samut Prakarn
# Done 151: (13.732284232432393,100.5471845259578) Polo Park, Pathum Wan Bangkok
# Done 152: (13.88290637106645,100.5885388928716) Pool Thip Condo House, Lak Si Bangkok
# Done 153: (13.91147817106645,100.5534007928716) Popular Condo, Pak Kret Nonthaburi
# Done 154: (12.874543232432393,100.8957254259578) Porch Land 2 Jomtien Resort, Bang Lamung Chonburi
# Done 155: (13.820432432432392,100.5235976259578) Pornpiya Mansion, Bang Sue Bangkok
# Done 156: (13.717868371066452,100.4538422928716) Porntaweewat Pechkasem, Bangkok
# Done 157: (13.746813732432393,100.4627458259578) Pracha Ruamjai Condotown Condo,
# Done 158: (13.781878132432393,100.5824042259578) Pradya Place Ratchada - Huai Khwang, Huai Khwang Bangkok
# Done 159: (13.74135227106645,100.5629864928716) Prasanmit Condominium, Watthana Bangkok
# Done 160: (13.740574071066451,100.5628927928716) Prasarnmit Place, Watthana Bangkok
# Done 161: (13.796983532432392,100.56458962595781) Prasertsuk Place, Bangkok
# Done 162: (13.75216217106645,100.5367665928716) Pratunam Prestige, Bangkok
# Done 163: (13.706497232432392,100.4909668259578) Prayapirom Chateau Riverboat, Thon Buri Bangkok
# Done 164: (13.720615132432393,100.5406486259578) Predee Place, Suan Luang Bangkok
# Done 165: (13.735873832432393,100.5488239259578) Preen by Sansiri, Pathum Wan Bangkok
# Done 166: (13.734101832432392,100.5583203259578) Prem Mansion, Khlong Toei Bangkok
# Done 167: (13.609346432432393,100.8484129259578) Preme Condo ABAC Bangna, Bang Bo Samut Prakarn
# Done 168: (13.607356171066451,100.8437505928716) Preme Lakeview, Bang Bo Samut Prakarn
# Done 169: (13.727426171066451,100.5686249928716) Premier Sukhumvit 24, Khlong Toei Bangkok
# Done 170: (13.73274347106645,100.5795882928716) Premier Thonglor, Watthana Bangkok
# Done 171: (13.742720632432393,100.6194517259578) Premiere Place Rama 9, Suan Luang Bangkok
# Done 172: (13.863054732432392,100.6162144259578) Premio Fresco, Bang Khen Bangkok
# Done 173: (13.832088832432392,100.6138715259578) Premio Prime, Lat Phrao Bangkok
# Done 174: (13.835414932432393,100.57325572595781) Premio Quinto, Chatuchak Bangkok
# Done 175: (13.84110727106645,100.5721547928716) Premio Vetro, Chatuchak Bangkok
# Done 176: (13.826573171066451,100.6212028928716) Premio by Premium Place, Lat Phrao Bangkok
# Done 177: (13.839672732432392,100.5817797259578) Premsiri Boutique Park, Chatuchak Bangkok
# Done 178: (13.688633332432392,100.4504851259578) Present Condominium, Chom Thong Bangkok
# Done 179: (13.78364427106645,100.4675677928716) President Condotown, Bangkok Noi Bangkok
# Done 180: (13.721728132432393,100.5659739259578) President Park Condo,
# Done 181: (13.745807432432393,100.5418032259578) President Place, Pathum Wan Bangkok
# Done 182: (13.740931732432392,100.5645148259578) Prestige Towers, Watthana Bangkok
# Done 183: (13.71519937106645,100.6420990928716) Prima Srinakarin, Suan Luang Bangkok
# Done 184: (12.95513157106645,100.88650859287159) Prima Wongamat, Bang Lamung Chonburi
# Done 185: (13.799700232432393,100.6059541259578) Prime I-Zen Condo Ladprao 71, Lat Phrao Bangkok
# Done 186: (13.73860217106645,100.5726859928716) Prime Mansion Promphong, Watthana Bangkok
# Done 187: (13.736979832432393,100.5752341259578) Prime Mansion Promsri, Watthana Bangkok
# Done 188: (13.739392532432392,100.5673932259578) Prime Mansion Sukhumvit 31, Watthana Bangkok
# Done 189: (18.803633132432395,98.9705395259578) Prime Square, Muang Chiang Mai Chiang Mai
# Done 190: (12.935338771066451,100.8974573928716) Prime Suites, Bang Lamung Chonburi
# Done 191: (13.734910832432393,100.5469169259578) Prive by Sansiri, Pathum Wan Bangkok
# Done 192: (13.713148632432393,100.4264730259578) Prodigy MRT Bangkhae, Phasi Charoen Bangkok
# Done 193: (13.777328232432392,100.5466545259578) Prom Phaholyothin 2, Phaya Thai Bangkok
# Done 194: (13.766786432432392,100.6458095259578) Prompimarn, Bang Kapi Bangkok
# Done 195: (18.80418713243239,98.9684349259578) Prompt Condo Chiangmai, Muang Chiang Mai Chiang Mai
# Done 196: (6.998195332432393,100.5028421259578) Prompt Condo Hatyai, Hat Yai Songkhla
# Done 197: (13.820147232432392,100.5841912259578) Prompto Condo Ratchada 32, Chatuchak Bangkok
# Done 198: (13.668299332432392,101.0582844259578) Proud Chachoengsao, Muang Chachoengsao Chachoengsao
# Done 199: (13.906171632432393,100.5311387259578) Proud III Chaengwattana, Pak Kret Nonthaburi
# Done 200: (13.64105307106645,100.4777951928716) Proud Posto Rama 2 - Phutthabucha, Thung Khru Bangkok
# Done 201: (13.906568432432392,100.5294729259578) Proud X2, Pak Kret Nonthaburi
# Done 202: (13.90656957106645,100.5294715928716) Proud of Chaengwattana, Pak Kret Nonthaburi
# Done 203: (13.85580367106645,100.5068047928716) Prow Life Ngamwongwan 15, Muang Nonthaburi Nonthaburi
# Done 204: (13.720371271066451,100.6687397928716) Prueksa Thani 3 Condotel, Prawet Bangkok
# Done 205: (13.72163257106645,100.6819017928716) Prueksa Thani Life Condotel, Prawet Bangkok
# Done 206: (7.89136047106645,98.3009313928716) Pu Condo, Kathu Phuket
# Done 207: (18.796105232432396,99.0198877259578) Punna Oasis 1, Muang Chiang Mai Chiang Mai
# Done 208: (18.79577633243239,99.0196277259578) Punna Oasis 2, Muang Chiang Mai Chiang Mai
# Done 209: (18.797479032432392,98.9651184259578) Punna Residence 1 @ Nimman, Muang Chiang Mai Chiang Mai
# Done 210: (18.806097832432393,98.95812582595781) Punna Residence 3 @ CMU, Muang Chiang Mai Chiang Mai
# Done 211: (18.806097832432393,98.95812582595781) Punna Residence 4 @ CMU, Muang Chiang Mai Chiang Mai
# Done 212: (18.805489432432395,98.9585944259578) Punna Residence 5, Muang Chiang Mai Chiang Mai
# Done 213: (12.788226432432392,100.9080989259578) Pure Sunset Beach, Sattahip Chonburi
# Done 214: (13.751922832432392,100.53101752595781) Pyne by Sansiri, Ratchathewi Bangkok
# Done 215: (13.740338032432392,100.5553067259578) Q 1 Sukhumvit, Khlong Toei Bangkok
# Done 216: (13.748400232432392,100.5628273259578) Q Asoke, Ratchathewi Bangkok
# Done 217: (13.749127532432393,100.5438181259578) Q Chidlom - Phetchaburi, Ratchathewi Bangkok
# Done 218: (19.93618183243239,99.8448691259578) Q House Condo Phaholyothin-Chiangrai, Muang Chiang Rai Chiang Rai
# Done 219: (13.707596832432392,100.6007246259578) Q House Condo Sukhumvit 79, Watthana Bangkok
# Done 220: (13.72140527106645,100.5013765928716) Q House Sathorn, Khlong San Bangkok
# Done 221: (13.739116732432393,100.5425992259578) Q Langsuan, Pathum Wan Bangkok
# Done 222: (13.743598032432393,100.5671857259578) Q Prasarnmit, Watthana Bangkok
# Done 223: (12.666241632432392,99.9570346259578) Q Seaside Huahin, Cha-Am Petchburi
# Done 224: (13.77471257106645,100.5744460928716) QUINTARA MHy’GEN RATCHADA - HUAI KHWANG, Huai Khwang Bangkok
# Done 225: (13.715842232432392,100.5862649259578) QUINTARA TREEHAUS SUKHUMVIT42, Khlong Toei Bangkok
# Done 226: (13.717350932432392,100.53059312595781) Quad Sathon, Sathon Bangkok
# Done 227: (13.72396997106645,100.5302229928716) Quad Suites Silom, Bang Rak Bangkok
# Done 228: (13.727856832432392,100.5814056259578) Quattro by Sansiri, Watthana Bangkok
# Done 229: (13.786640032432393,100.5732432259578) Quinn Ratchada 17, Din Daeng Bangkok
# Done 230: (13.689940332432393,100.6090424259578) Quinn Sukhumvit 101, Phra Khanong Bangkok
# Done 231: (13.702956132432393,100.5992406259578) Quintara Arte Sukhumvit 52, Pathum Wan Bangkok
# Done 232: (13.744308332432393,100.5740481259578) Quintara Phume Sukhumvit 39, Watthana Bangkok
# Done 233: (13.894527832432393,100.6116751259578) REACH Phahon Yothin 52 Condo, Bangkok
# Done 234: (13.894077632432392,100.5640850259578) RESTA PANO, Lak Si Bangkok
# Done 235: (13.70976707106645,100.5117875928716) RHYTHM CHAROENKRUNG PAVILLION, Bang Kho Laem Bangkok
# Done 236: (13.72928557106645,100.5858296928716) RHYTHM EKKAMAI ESTATE, Watthana Bangkok
# Done 237: (13.739173032432392,100.6465905259578) RYE Huamak, Suan Luang Bangkok
# Done 238: (13.685344132432393,100.62483382595781) RYE Sukhumvit 101/1, Phra Khanong Bangkok
# Done 239: (13.71670697106645,100.4760207928716) RYE Talat Phlu, Thon Buri Bangkok
# Done 240: (13.831175632432393,100.5609835259578) Rachwipa Place, Chatuchak Bangkok
# Done 241: (8.12420507106645,98.3015762928716) Radisson Phuket Mai Khao Beach, Thalang Phuket
# Done 242: (12.728899832432392,99.9616539259578) Rain Cha Am - Hua Hin, Hua Hin Prachaubkirikhan
# Done 243: (13.731275632432393,100.5784249259578) Raintree Villa, Watthana Bangkok
# Done 244: (13.730113032432392,100.5643008259578) Raj Mansion, Khlong Toei Bangkok
# Done 245: (13.763049532432392,100.5420161259578) Rajvithi City Resort, Ratchathewi Bangkok
# Done 246: (13.163632171066451,100.9195855928716) Rama Harbour view condo, Si Racha Chonburi
# Done 247: (13.80570827106645,100.5143290928716) Rama VI Mansion, Bang Phlat Bangkok
# Done 248: (13.70156457106645,100.6032908928716) Ramada Residence Condo,
# Done 249: (13.70895507106645,100.5985403928716) Ramada plaza residence
# Done 250: (13.820017871066451,100.5835035928716) Ratchaarpa Tower, Chatuchak Bangkok
# Done 251: (13.816615432432393,100.5798110259578) Ratchada Chuanchom Mansion, Bangkok
# Done 252: (13.783518732432393,100.5851814259578) Ratchada City 18, Din Daeng Bangkok
# Done 253: (13.780224371066451,100.5777374928716) Ratchada City Condo, Huai Khwang Bangkok
# Done 254: (13.787025032432393,100.5785423259578) Ratchada Orchid
# Done 255: (13.78069937106645,100.5715334928716) Ratchada Pavilion, Bangkok
# Done 256: (13.795332932432393,100.5883596259578) Ratchada Prestige, Huai Khwang Bangkok
# Done 257: (7.898543932432393,98.3490156259578) Ratchaporn Place, Kathu Phuket
# Done 258: (13.766945471066451,100.60547809287159) Ratchapruek Condo, Phasi Charoen Bangkok
# Done 259: (13.75334447106645,100.5341365928716) Ratchathewi Tower Condo,
# Done 260: (13.832640471066451,100.5686779928716) Ratchayothin Place, Chatuchak Bangkok
# Done 261: (13.749997532432392,100.4922745259578) Rattanakosin Island, Bangkok
# Done 262: (13.763807732432392,100.4910835259578) Rattanakosin View Mansion, Bang Phlat Bangkok
# Done 263: (13.739198132432392,100.5703104259578) Raveevan Suites, Watthana Bangkok
# Done 264: (7.8009103710664505,98.3363557928716) Rawai Seaview, Muang Phuket Phuket
# Done 265: (18.796053832432392,98.9668908259578) Rawee Waree Residence, Muang Chiang Mai Chiang Mai
# Done 266: (13.764924832432392,100.6326867259578) Raymond Tower, Bang Kapi Bangkok
# Done 267: (12.676105832432393,101.2720842259578) Rayong Riverside Residence, Muang Rayong Rayong
# Done 268: (12.689268632432393,101.24028902595781) Rayong Royal Peak 2, Muang Rayong Rayong
# Done 269: (13.719920032432393,100.4939723259578) Reference Sathorn - Wongwianyai, Khlong San Bangkok
# Done 270: (12.864602332432392,100.8940722259578) Reflection Jomtien Beach Pattaya, Sattahip Chonburi
# Done 271: (13.667158632432393,100.6401360259578) Regal Bangna - Sri Iam Interchange, Bang Na Bangkok
# Done 272: (13.706356432432392,100.5385796259578) Regal Sathon - Naradhiwas, Sathon Bangkok
# Done 273: (13.888334132432393,100.6000763259578) Regent Home 1 Phaholyothin 67, Bang Khen Bangkok
# Done 274: (13.876879332432393,100.5950373259578) Regent Home 10 Changwattana, Bang Khen Bangkok
# Done 275: (13.802337132432392,100.5871730259578) Regent Home 12 Latphrao 41
# Done 276: (13.701463432432393,100.6119859259578) Regent Home 13 Sukhumvit 93, Bangkok
# Done 277: (13.703268932432392,100.60895342595781) Regent Home 14 Sukhumvit 93, Phra Khanong Bangkok
# Done 278: (13.877893032432393,100.5942512259578) Regent Home 15 Changwattana, Bang Khen Bangkok
# Done 279: (13.88833527106645,100.6000749928716) Regent Home 16 Phaholyotin 67, Bang Khen Bangkok
# Done 280: (13.700199332432392,100.6084671259578) Regent Home 19 Sukhumvit 93, Phra Khanong Bangkok
# Done 281: (13.816184532432393,100.5348242259578) Regent Home 20 Prachachuen 16, Bang Sue Bangkok
# Done 282: (13.704869832432392,100.6069914259578) Regent Home 22 Sukhumvit 85, Phra Khanong Bangkok
# Done 283: (13.847075432432392,100.5159286259578) Regent Home 25 Tiwanon, Muang Nonthaburi Nonthaburi
# Done 284: (13.819519232432393,100.5302443259578) Regent Home 27 Bangson, Bang Sue Bangkok
# Done 285: (13.880019671066451,100.5974383928716) Regent Home 3, Bang Khen Bangkok
# Done 286: (13.705304832432393,100.6091914259578) Regent Home 4, Phra Khanong Bangkok
# Done 287: (13.800305132432392,100.5711797259578) Regent Home 5 Ratchada 19, Chatuchak Bangkok
# Done 288: (13.825367571066451,100.5445447928716) Regent Home 6/1 Prachacheun, Chatuchak Bangkok
# Done 289: (13.82514527106645,100.5455822928716) Regent Home 6/2 Prachacheun, Chatuchak Bangkok
# Done 290: (13.67572447106645,100.6040924928716) Regent Home 7 Bang na, Bang Na Bangkok
# Done 291: (13.689308332432393,100.6026103259578) Regent Home 9 Sukhumvit 64, Phra Khanong Bangkok
# Done 292: (13.81845477106645,100.5290704928716) Regent Home Bangson Phase 28, Bang Sue Bangkok
# Done 293: (13.706322332432393,100.6081256259578) Regent Home Sukhumvit 81, Suan Luang Bangkok
# Done 294: (13.699937632432393,100.6141829259578) Regent Home Sukhumvit 97/1, Phra Khanong Bangkok
# Done 295: (13.713543732432392,100.4717934259578) Regent Home Wutthakat, Thon Buri Bangkok
# Done 296: (13.742469132432392,100.5732276259578) Regent On The Park 5, Watthana Bangkok
# Done 297: (13.690642632432393,100.6112334259578) Regent Orchid Sukhumvit 101, Phra Khanong Bangkok
# Done 298: (13.716681832432393,100.4761919259578) Regent Orchid Talad Plu, Thon Buri Bangkok
# Done 299: (13.784507471066451,100.5698565928716) Regent Ratchada Tower, Din Daeng Bangkok
# Done 300: (13.736508671066451,100.5405167928716) Regent Royal Place 1, Pathum Wan Bangkok
# Done 301: (13.739632632432393,100.5416611259578) Regent Royal Place 2, Pathum Wan Bangkok
# Done 302: (13.730366932432393,100.6400984259578) Regent Srinakarin Tower Condo,
# Done 303: (13.877543232432393,100.5947425259578) Regent home 18 changwattana-laksi, Bang Khen Bangkok
# Done 304: (13.673680632432392,100.6024201259578) Regent home bangna, Bang Na Bangkok
# Done 305: (13.726062732432393,100.5691864259578) Regent on the Park 1, Khlong Toei Bangkok
# Done 306: (13.726829332432393,100.5833300259578) Regent on the Park 2, Watthana Bangkok
# Done 307: (13.742301771066451,100.57340899287159) Regent on the Park 3 Condo,
# Done 308: (13.739049932432392,100.5642851259578) Rende Sukhumvit 23, Watthana Bangkok
# Done 309: (13.745593132432392,100.5494675259578) Renova Residence Chidlom, Pathum Wan Bangkok
# Done 310: (13.743469132432393,100.5553580259578) Residence 187, Watthana Bangkok
# Done 311: (13.702317332432392,100.5990206259578) Residence 52, Phra Khanong Bangkok
# Done 312: (13.792743932432392,100.5628846259578) Residency Height Condominium, Din Daeng Bangkok
# Done 313: (13.71092327106645,100.5485965928716) Resorta Yen-akat, Yan Nawa Bangkok
# Done 314: (13.89435707106645,100.5641129928716) Resta Resort Condo, Lak Si Bangkok
# Done 315: (13.863686171066451,100.4980599928716) Rewadee Condiminium, Muang Nonthaburi Nonthaburi
# Done 316: (13.777985671066451,100.5744859928716) Rhythm  Ratchada, Huai Khwang Bangkok
# Done 317: (13.754427032432393,100.5641077259578) Rhythm Asoke, Ratchathewi Bangkok
# Done 318: (13.753837432432393,100.5650075259578) Rhythm Asoke ll, Huai Khwang Bangkok
# Done 319: (13.72282457106645,100.5841589928716) Rhythm Ekkamai, Watthana Bangkok
# Done 320: (13.788953632432392,100.5454557259578) Rhythm Phahol - Ari, Phaya Thai Bangkok
# Done 321: (13.761033532432393,100.5369706259578) Rhythm Rangnam, Ratchathewi Bangkok
# Done 322: (13.777985671066451,100.5744859928716) Rhythm Ratchada - Huai Khwang, Din Daeng Bangkok
# Done 323: (13.71695927106645,100.51661529287159) Rhythm Sathorn, Sathon Bangkok
# Done 324: (13.718850332432392,100.5324100259578) Rhythm Sathorn - Narathiwas Condo,
# Done 325: (13.721868232432392,100.5769033259578) Rhythm Sukhumvit 36 - 38, Khlong Toei Bangkok
# Done 326: (13.717752732432393,100.5853450259578) Rhythm Sukhumvit 42, Khlong Toei Bangkok
# Done 327: (13.715171232432393,100.5908518259578) Rhythm Sukhumvit 44/1, Khlong Toei Bangkok
# Done 328: (13.706515532432393,100.5995040259578) Rhythm Sukhumvit 50, Khlong Toei Bangkok
# Done 329: (13.870525732432393,100.4695488259578) Rich Park @ Chaophraya, Muang Nonthaburi Nonthaburi
# Done 330: (13.737324932432392,100.6429833259578) Rich Park @ Triple Station, Suan Luang Bangkok
# Done 331: (13.805852832432393,100.5288502259578) Rich Park @Taopoon Interchange, Bang Sue Bangkok
# Done 332: (13.882432532432393,100.6004863259578) Rich Park Terminal @Phahonyothin 59, Lak Si Bangkok
# Done 333: (13.730588332432392,100.57468762595781) Richmond Palace, Watthana Bangkok
# Done 334: (13.822886332432393,100.5322618259578) Richpark @ Bangson Station, Bang Sue Bangkok
# Done 335: (13.971356132432392,100.6040417259578) Rill Condo, Muang Pathum Thani Pathumthani
# Done 336: (13.687873732432392,100.5101381259578) Rimtara Residence, Bang Kho Laem Bangkok
# Done 337: (13.741875832432392,100.5717064259578) Rin House, Watthana Bangkok
# Done 338: (13.788864632432393,100.5531400259578) Rise Phahon - Inthamara, Phaya Thai Bangkok
# Done 339: (13.751092632432393,100.5985356259578) Rise Rama 9, Huai Khwang Bangkok
# Done 340: (13.702105132432392,100.5002583259578) River Heaven, Bangkok
# Done 341: (13.730130332432392,100.5104546259578) River House Condominium, Khlong San Bangkok
# Done 342: (13.961725171066451,100.6274984928716) River Park Condotel, Lam Luk Ka Pathumthani
# Done 343: (13.828583132432392,100.5006979259578) Riverine Place, Muang Nonthaburi Nonthaburi
# Done 344: (13.70523017106645,100.49106369287159) Riverside Villa, Bang Kho Laem Bangkok
# Done 345: (12.88259917106645,100.8861069928716) Riviera Muangtongtani
# Done 346: (13.927935432432392,100.5328258259578) Riviera up, Pak Kret Nonthaburi
# Done 347: (13.840941332432392,100.4423744259578) Rizzo Condo Bangkrang, Muang Nonthaburi Nonthaburi
# Done 348: (18.787567732432393,98.9725356259578) Rooks Condotel, Muang Chiang Mai Chiang Mai
# Done 349: (12.922966132432393,100.8627737259578) Royal Beach Condotel, Bang Lamung Chonburi
# Done 350: (13.734372571066451,100.57200819287159) Royal Castle Condo,
# Done 351: (12.926641532432393,100.8624612259578) Royal Cliff Garden, Bang Lamung Chonburi
# Done 352: (13.02657647106645,101.0819622928716) Royal Hill Resort, Si Racha Chonburi
# Done 353: (7.953574271066451,98.3830013928716) Royal Kamala Phuket, Kathu Phuket
# Done 354: (13.758639832432392,100.5915724259578) Royal Nine Residence, Huai Khwang Bangkok
# Done 355: (13.780147232432393,100.54232192595781) Royal Park 3 Ari - Paholyothin, Phaya Thai Bangkok
# Done 356: (13.734508232432393,100.5464736259578) Royal Residence Park, Pathum Wan Bangkok
# Done 357: (13.673570132432392,100.5456921259578) Royal River Place Condo,
# Done 358: (13.757711571066451,100.5337052928716) Royal Tower 3 CondoPhaya Thai Bangkok
# Done 359: (13.901933132432392,100.5293376259578) Royal Tower Condominium, Pak Kret Nonthaburi
# Done 360: (13.740355332432392,100.5660563259578) Royce Private Residences, Watthana Bangkok
# Done 361: (12.910490171066451,100.8590200928716) Ruamchok Condo View 1, Bang Lamung Chonburi
# Done 362: (12.910941232432393,100.8575190259578) Ruamchok Condo View 2, Bang Lamung Chonburi
# Done 363: (13.747191232432392,100.5588343259578) Ruamjai Heights, Watthana Bangkok
# Done 364: (13.736508671066451,100.5405167928716) Ruamrudee Garden House, Pathum Wan Bangkok
# Done 365: (13.734680371066451,100.5482301928716) Ruamrudee House, Samphanthawong Bangkok
# Done 366: (13.721384932432393,100.5707109259578) Ruamsuk Condo, Khlong Toei Bangkok
# Done 367: (13.72653097106645,100.5674452928716) Ruansap Condo, Thung Khru Bangkok
# Done 368: (13.736200132432392,100.5508526259578) Rudee Place, Pathum Wan Bangkok
# Done 369: (13.67887147106645,100.4683364928716) Ruenrom Condominium 2, Bang Kapi Bangkok
# Done 370: (13.745548132432393,100.5512590259578) Ruenrudee Condominium, Watthana Bangkok
# Done 371: (13.730949832432392,100.5794531259578) Runesu Thonglor 5, Watthana Bangkok
# Done 372: (13.772350432432393,100.5965958259578) Rungrueng Condo Town, Wang Thonglang Bangkok
# Done 373: (13.42181777106645,101.0405900928716) S 1 park, Muang Chon Buri Chonburi
# Done 374: (18.796469232432393,98.97240892595781) S Condo Chiangmai, Muang Chiang Mai Chiang Mai
# Done 375: (13.568148832432392,100.27286822595781) S Condo Samutsakhon, Muang Samut Sakhon Samut Sakhon
# Done 376: (13.703483032432393,100.5907163259578) S Condo Sukhumvit 50, Khlong Toei Bangkok
# Done 377: (12.911372932432393,100.8940474259578) S Fifty South Pattaya, Bang Lamung Chonburi
# Done 378: (13.711087232432392,100.5928955259578) S&S Sukhumvit, Phra Khanong Bangkok
# Done 379: (13.740230532432392,100.5677131259578) S.C.C. Residence, Watthana Bangkok
# Done 380: (13.726057332432392,100.5403780259578) S.L.D. Condo, Bang Rak Bangkok
# Done 381: (13.672492871066451,100.54402749287159) S.V. City Rama 3, Yan Nawa Bangkok
# Done 382: (13.743982632432392,100.6304326259578) S1 Rama 9, Suan Luang Bangkok
# Done 383: (13.731048732432393,100.5744102259578) S47 Sukhumvit, Watthana Bangkok
# Done 384: (13.87830847106645,100.4466338928716) S9, Bang Bua Thong Nonthaburi
# Done 385: (13.785272032432392,100.5434361259578) SAVVI ARI 4, Phaya Thai Bangkok
# Done 386: (13.742438232432393,100.54412772595781) SCOPE Langsuan, Pathum Wan Bangkok
# Done 387: (13.737087232432392,100.5761278259578) SCOPE PROMSRI, Watthana Bangkok
# Done 388: (18.785424971066448,98.9684232928716) SD Chiang Mai, Muang Chiang Mai Chiang Mai
# Done 389: (13.70377317106645,100.4217568928716) SENA Kith MRT - Bangkae, Bang Khae Bangkok
# Done 390: (13.70495157106645,100.4216764928716) SENA Kith MRT Bangkae Phase 2, Bang Khae Bangkok
# Done 391: (13.76497627106645,100.2323879928716) SENA Kith Phetkasem - Phutthamonthon Sai 7, Sam Phran Nakhon Pathom
# Done 392: (13.703092732432392,100.5970006259578) SIGN Sukhumvit 50, Khlong Toei Bangkok
# Done 393: (13.73688227106645,100.4381818928716) SJ Residence Bangwaek 63
# Done 394: (13.890064732432393,100.6049767259578) SO Origin Phahol 69 Station, Bang Khen Bangkok
# Done 395: (13.788365532432392,100.5528023259578) SOCIO Inthamara, Phaya Thai Bangkok
# Done 396: (13.724736932432393,100.5833309259578) SOCIO Reference 61, Watthana Bangkok
# Done 397: (13.778530432432392,100.5758319259578) SOHO BANGKOK RATCHADA, Huai Khwang Bangkok
# Done 398: (13.730605432432393,100.5828967259578) SP Mansion Thong lor, Watthana Bangkok
# Done 399: (7.890071532432392,98.3625418259578) SPACE Condominium Phuket, Muang Phuket Phuket
# Done 400: (18.784978232432394,99.0233307259578) SR Complex, Muang Chiang Mai Chiang Mai
# Done 401: (13.75324557106645,100.4681782928716) SUN CITY MRT Yaek Fai Chai, Bangkok Noi Bangkok
# Done 402: (13.654263232432392,100.6100447259578) SUPALAI City Resort SUKHUMVIT 107, Muang Samut Prakarn Samut Prakarn
# Done 403: (13.806906632432392,100.5586749259578) SYM Vibha - Ladprao, Chatuchak Bangkok
# Done 404: (13.63710807106645,100.59490999287159) Sabai Sabai Condo Sukhumvit 115, Muang Samut Prakarn Samut Prakarn
# Done 405: (13.715616032432392,100.5078245259578) Saichol Mansion, Khlong San Bangkok
# Done 406: (13.643970232432393,100.6005972259578) Sailom Condotel, Muang Samut Prakarn Samut Prakarn
# Done 407: (13.832878932432392,100.57846102595781) Sailom Suite, Chatuchak Bangkok
# Done 408: (13.761172832432392,100.5385752259578) Saitharn Condominium, Ratchathewi Bangkok
# Done 409: (13.72913527106645,100.5348285928716) Saladaeng Colonnade, Bang Rak Bangkok
# Done 410: (13.727021032432393,100.5371688259578) Saladaeng Executive, Bang Rak Bangkok
# Done 411: (13.726631971066451,100.5411449928716) Saladaeng One
# Done 412: (13.725354232432393,100.5381880259578) Saladaeng Residences, Bang Rak Bangkok
# Done 413: (13.79921897106645,100.3124106928716) Salaya Condo, Phuttha Mon Thon Nakhon Pathom
# Done 414: (13.687316332432392,100.5104157259578) Salintara Condo,
# Done 415: (13.77599197106645,100.67371599287159) Sammakorn Ramkhamhaeng, Saphan Sung Bangkok
# Done 416: (13.309855032432392,100.9027833259578) Sammuk Terrace Condominium, Muang Chon Buri Chonburi
# Done 417: (13.722156632432393,100.5250591259578) Sampoom Garden, Bang Rak Bangkok
# Done 418: (13.776646032432392,100.5824597259578) Samran Mansion, Huai Khwang Bangkok
# Done 419: (13.62518667106645,100.6808104928716) Samut Malee Condominium, Phra Pra Daeng Samut Prakarn
# Done 420: (12.910302932432392,100.8571960259578) Sands Condominium, Bang Lamung Chonburi
# Done 421: (12.453103871066451,99.9810098928716) Santorini (Huahin Cliff View), Pran Buri Prachaubkirikhan
# Done 422: (13.738808232432392,100.5544175259578) Saranjai Mansion, Khlong Toei Bangkok
# Done 423: (13.777817371066451,100.6410897928716) Saranville @ Happy Land, Bang Kapi Bangkok
# Done 424: (13.687292232432393,100.6067157259578) Sari by Sansiri, Phra Khanong Bangkok
# Done 425: (13.830146332432392,100.5645362259578) Sarin Place, Chatuchak Bangkok
# Done 426: (13.838182132432392,100.51347542595781) Saritdet Condominium, Muang Nonthaburi Nonthaburi
# Done 427: (13.719141032432393,100.5064648259578) Sathorn Bridge Tower, Khlong San Bangkok
# Done 428: (13.736508671066451,100.5405167928716) Sathorn Condo Place Condo,
# Done 429: (13.729227432432392,100.5660732259578) Sathorn Crest
# Done 430: (13.721035232432392,100.5237187259578) Sathorn Gallery Residences, Bang Rak Bangkok
# Done 431: (13.722710332432392,100.53877042595781) Sathorn Gardens Condo,
# Done 432: (13.716827132432392,100.5296078259578) Sathorn Happy Land Tower, Sathon Bangkok
# Done 433: (13.71767647106645,100.5255469928716) Sathorn Heritage, Sathon Bangkok
# Done 434: (13.72012847106645,100.5211602928716) Sathorn House, Bang Rak Bangkok
# Done 435: (13.723572032432392,100.5393758259578) Sathorn Park Place, Sathon Bangkok
# Done 436: (13.736508671066451,100.5405167928716) Sathorn Place, Khlong San Bangkok
# Done 437: (13.715868432432393,100.5471469259578) Sathorn Plus By The Garden, Yan Nawa Bangkok
# Done 438: (13.715636032432393,100.5469675259578) Sathorn Plus On The Pond, Yan Nawa Bangkok
# Done 439: (13.71611727106645,100.5309211928716) Sathorn Prime Residence, Sathon Bangkok
# Done 440: (13.736508671066451,100.5405167928716) Sathorn Residence, Khlong San Bangkok
# Done 441: (13.716788171066451,100.5297489928716) Sathorn Suite Condo,
# Done 442: (13.864824371066451,100.54438559287159) Sattanathibet Mansion, Muang Nonthaburi Nonthaburi
# Done 443: (7.804126432432392,98.3310357259578) Saturdays Residence, Muang Phuket Phuket
# Done 444: (13.778349732432392,100.5465967259578) Savvi Phahol - Ari, Phaya Thai Bangkok
# Done 445: (13.777307332432393,100.5466881259578) Savvi Phahol 2, Phaya Thai Bangkok
# Done 446: (13.720362432432392,100.5321546259578) Sawang Apartment, Sathon Bangkok
# Done 447: (13.741843632432392,100.5679370259578) Sawasdee Mansion, Watthana Bangkok
# Done 448: (13.738909332432392,100.5824695259578) Sawit Suites, Watthana Bangkok
# Done 449: (8.058482032432392,98.2781731259578) Sea Heaven, Thalang Phuket
# Done 450: (13.14356577106645,100.9140476928716) Sea Hill Condo, Si Racha Chonburi
# Done 451: (12.764404032432392,100.8966803259578) Sea Saran Bang Saray Beach, Sattahip Chonburi
# Done 452: (12.759830371066451,100.88312919287159) Sea Zen Bang Saray, Bang Lamung Chonburi
# Done 453: (13.975881532432393,100.5806289259578) Sena Eco Town Rangsit Station, Muang Pathum Thani Pathumthani
# Done 454: (13.888614632432393,100.6109629259578) Sena Kith BTS Saphanmai, Sai Mai Bangkok
# Done 455: (13.765783832432392,100.8047363259578) Sena Kith Chalong Krung - Ladkrabang, Lat Krabang Bangkok
# Done 456: (13.631159932432393,100.6264842259578) Sena Kith Srinakarin - Sridan, Muang Samut Prakarn Samut Prakarn
# Done 457: (13.940424632432393,100.3885998259578) Sena Kith Westgate - Bangbuathong, Bang Bua Thong Nonthaburi
# Done 458: (13.539277432432392,100.6178974259578) Sena Miami Ecotown Sukhumvit - Bangpu, Muang Samut Prakarn Samut Prakarn
# Done 459: (13.789113332432393,100.55230382595781) Sense Phaholyothin, Phaya Thai Bangkok
# Done 460: (13.678122232432392,100.6067253259578) Sense Sukhumvit, Bang Na Bangkok
# Done 461: (13.65616937106645,100.6031752928716) Sense of London, Muang Samut Prakarn Samut Prakarn
# Done 462: (7.981090732432392,98.2873700259578) Serene Condominium, Thalang Phuket
# Done 463: (13.736508671066451,100.5405167928716) Serene Place, Khlong Toei Bangkok
# Done 464: (7.800909232432392,98.3363571259578) Serenity Resort & Residences, Muang Phuket Phuket
# Done 465: (12.969313932432392,100.8852668259578) Serenity Wongamat, Bang Lamung Chonburi
# Done 466: (18.764076571066454,98.9762678928716) Sereno Airport, Muang Chiang Mai Chiang Mai
# Done 467: (13.705400532432392,100.5974433259578) Serio Sukhumvit 50, Khlong Toei Bangkok
# Done 468: (13.72297267106645,100.5799831928716) Serm Siri Condo, Bang Khen Bangkok
# Done 469: (13.665438032432393,100.4329901259578) Serrano Condominium Rama II, Bang Khun Thian Bangkok
# Done 470: (12.878512432432393,100.8920091259578) Seven Seas Condo Resort Jomtien, Bang Lamung Chonburi
# Done 471: (12.859011332432393,100.9001990259578) Seven Seas Cote d Azur, Sattahip Chonburi
# Done 472: (18.810177571066454,98.9672897928716) Seven Star Condo, Muang Chiang Mai Chiang Mai
# Done 473: (13.354534132432393,100.9742280259578) Shore Residence, Muang Chon Buri Chonburi
# Done 474: (13.732147032432392,100.5143773259578) Si Phraya River View, Samphanthawong Bangkok
# Done 475: (13.037251932432392,101.0874775259578) Siam City Condo, Si Racha Chonburi
# Done 476: (13.75895257106645,100.5672157928716) Siam Condominium Condo,
# Done 477: (12.913094071066451,100.8618605928716) Siam Oriental Elegance 2, 357/83 Bang Lamung Chonburi
# Done 478: (12.914193071066451,100.8615579928716) Siam Oriental Garden, Bang Lamung Chonburi
# Done 479: (12.917256232432392,100.8631916259578) Siam Oriental Garden 2, Bang Lamung Chonburi
# Done 480: (12.915869432432393,100.8634392259578) Siam Oriental Plaza, Bang Lamung Chonburi
# Done 481: (12.913457132432393,100.86196442595781) Siam Oriental Tropical Garden, Bang Lamung Chonburi
# Done 482: (12.913987332432393,100.8618475259578) Siam Oriental Twins, Bang Lamung Chonburi
# Done 483: (13.737320232432392,100.5559165259578) Siam Penthouse 1, Khlong Toei Bangkok
# Done 484: (13.721423232432393,100.5455181259578) Siam Penthouse 2, Sathon Bangkok
# Done 485: (12.968511832432393,100.8846600259578) Siam Penthouse 3, Bang Lamung Chonburi
# Done 486: (13.716844832432393,100.5847805259578) Siamese Exclusive 42, Khlong Toei Bangkok
# Done 487: (13.723231032432393,100.5611185259578) Siamese Exclusive Queens, Khlong Toei Bangkok
# Done 488: (13.738211032432392,100.5663113259578) Siamese Exclusive Sukhumvit 31, Watthana Bangkok
# Done 489: (13.743032232432393,100.5711205259578) Siamese Gioia, Watthana Bangkok
# Done 490: (13.700322132432392,100.5445961259578) Siamese Nang Linchee, Yan Nawa Bangkok
# Done 491: (13.75503877106645,100.5837586928716) Siamese Rama 9, Huai Khwang Bangkok
# Done 492: (13.775831732432392,100.5429741259578) Siamese Ratchakru, Phaya Thai Bangkok
# Done 493: (13.721175071066451,100.5657186928716) Siamese Sukhumvit 87, Bangkok
# Done 494: (13.730030732432393,100.5279834259578) Siamese Surawong, Bang Rak Bangkok
# Done 495: (13.739298832432393,100.5726444259578) Siamese Thirty Nine, Watthana Bangkok
# Done 496: (13.774025732432392,100.54147432595781) Silk Phaholyothin 3, Phaya Thai Bangkok
# Done 497: (13.786379932432393,100.5433985259578) Silk Phaholyothin 9, Phaya Thai Bangkok
# Done 498: (13.878655432432392,100.5980119259578) Silk Place Pahonyothin - Laksi Condo,
# Done 499: (13.774399932432393,100.5416329259578) Silk Sanampao, Phaya Thai Bangkok
# Done 500: (13.724103832432393,100.5321848259578) Silom City Resort, Bang Rak Bangkok
# Done 501: (13.72761187106645,100.5347731928716) Silom Condominium, Bang Rak Bangkok
# Done 502: (13.727745532432392,100.5358718259578) Silom Grand Terrace, Bang Rak Bangkok
# Done 503: (13.727386632432392,100.5349025259578) Silom Park View, Bang Rak Bangkok
# Done 504: (13.72348667106645,100.5282812928716) Silom Suite, Bangkok
# Done 505: (13.727821132432393,100.5290567259578) Silom Surawong Condo,
# Done 506: (13.727244232432392,100.5345472259578) Silom Terrace
# Done 507: (12.96794547106645,100.8839086928716) Silver Beach, Bang Lamung Chonburi
# Done 508: (13.718572332432393,100.5794269259578) Silver Heritage, Khlong Toei Bangkok
# Done 509: (13.734476832432392,100.5417817259578) Sindhorn Lumpini, Pathum Wan Bangkok
# Done 510: (13.738729432432393,100.5439691259578) Sindhorn Residence, Pathum Wan Bangkok
# Done 511: (13.734425632432393,100.5442202259578) Sindhorn Tonson, Pathum Wan Bangkok
# Done 512: (13.75701667106645,100.6444698928716) Sinsetthee Resident Town, Bang Kapi Bangkok
# Done 513: (14.018198832432393,100.6179720259578) Sinthanee Classic Condo, Khlong Luang Pathumthani
# Done 514: (13.833605932432393,100.6628198259578) Sinthanee Residence Tower, Bangkok
# Done 515: (12.725059332432393,101.0668307259578) Sippapas, Ban Chang Rayong
# Done 516: (18.79671257106645,98.9721355928716) Siri Condo, Muang Chiang Mai Chiang Mai
# Done 517: (13.736979232432393,100.5561343259578) Siri On 8, Khlong Toei Bangkok
# Done 518: (13.728033132432392,100.5684755259578) Siri Residence, Khlong Toei Bangkok
# Done 519: (13.72348667106645,100.5282812928716) Siri Sathorn Residence, Bang Rak Bangkok
# Done 520: (13.722971532432393,100.5799845259578) Siri at Sukhumvit, Bangkok
# Done 521: (18.56350583243239,99.0364391259578) Siricondotel, Muang Lamphun Lamphun
# Done 522: (13.737383232432393,100.6260918259578) Sirin Residence, Bang Khen Bangkok
# Done 523: (13.737383232432393,100.6260918259578) Sirin Residence Pattanakarn, Suan Luang Bangkok
# Done 524: (13.746040632432392,100.54445852595781) Sithakarn Condominium, Pathum Wan Bangkok
# Done 525: (13.642086632432392,100.6713442259578) Sixth Element Na Jomtien, Chonburi
# Done 526: (12.94691087106645,100.8877570928716) Sixty Six Condominium, Bang Lamung Chonburi
# Done 527: (12.960818732432392,100.8866223259578) Sky Beach, Bang Lamung Chonburi
# Done 528: (13.720474832432393,100.5285119259578) Sky Villas, Sathon Bangkok
# Done 529: (13.714478532432393,100.5934937259578) Sky Walk Residence, Watthana Bangkok
# Done 530: (13.867156132432392,100.4907816259578) Skyline Rattanathibet, Muang Nonthaburi Nonthaburi
# Done 531: (13.684504332432393,100.6084823259578) Skyrise Avenue Sukhumvit 64, Phra Khanong Bangkok
# Done 532: (13.66079797106645,100.42704129287159) Smart Condo @ Rama 2, Bang Khun Thian Bangkok
# Done 533: (13.858356032432393,100.6460755259578) Smart Condo Watcharapol, Bang Khen Bangkok
# ...
# Done 1497: (12.606162132432393,101.3955652259578) Victory View Condominium, Muang Rayong Rayong
# Done 1498: (12.902645471066451,100.8709002928716) View Talay Jomtien Condominium, Bang Lamung Chonburi
# Done 1499: (12.902645471066451,100.8709002928716) View Talay Jomtien Condominium 2, Bang Lamung Chonburi
# Done 1500: (12.89838647106645,100.8716295928716) View Talay Jomtien Condominium 3, Bang Lamung Chonburi
# Done 1501: (12.901191671066451,100.8659940928716) View Talay Jomtien Condominium 5, Bang Lamung Chonburi
# Done 1502: (12.889679971066451,100.8953654928716) View Talay Jomtien Condominium 7, Bang Lamung Chonburi
# Done 1503: (12.879242832432393,100.8848107259578) View Talay Jomtien Condominium 8, Bang Lamung Chonburi
# Done 1504: (12.94767517106645,100.8856336928716) View Talay Pattaya Condominium 6, Bang Lamung Chonburi
# Done 1505: (12.899749271066451,100.8714061928716) View Talay Residence 1,2, Bang Lamung Chonburi
# Done 1506: (12.897959332432393,100.8719967259578) View Talay Residence 4, Bang Lamung Chonburi
# Done 1507: (12.957417432432392,100.8870786259578) View Talay Residence 6, Bang Lamung Chonburi
# Done 1508: (12.851993132432392,100.9001128259578) View Talay Sands Na Jomtien, Sattahip Chonburi
# Done 1509: (13.854646971066451,100.5394094928716) View Tower Condominium, Muang Nonthaburi Nonthaburi
# Done 1510: (13.601698432432393,100.8330747259578) Viia 7, Bang Sao Thong Samut Prakarn
# Done 1511: (13.601698432432393,100.8330747259578) Viia 7 Bangna, Bang Sao Thong Samut Prakarn
# Done 1512: (13.748570332432392,100.5616855259578) Villa Asoke, Ratchathewi Bangkok
# Done 1513: (13.985071832432393,100.5509948259578) Villa California, Muang Pathum Thani Pathumthani
# Done 1514: (13.771101532432393,100.61407542595781) Villa Chaya, Wang Thonglang Bangkok
# Done 1515: (13.736471032432393,100.5598940259578) Villa Fourteen, Khlong Toei Bangkok
# Done 1516: (13.66018917106645,100.6112699928716) Villa Lasalle, Bang Na Bangkok
# Done 1517: (13.77598817106645,100.5418454928716) Villa Rachakhru, Phaya Thai Bangkok
# Done 1518: (13.75423307106645,100.5327289928716) Villa Rachatewi, Ratchathewi Bangkok
# Done 1519: (13.721556232432393,100.5042711259578) Villa Sathorn, Khlong San Bangkok
# Done 1520: (13.740154232432392,100.5799566259578) Villa Sikhara, Watthana Bangkok
# Done 1521: (13.675964632432393,100.6438732259578) Villcher Condominium, Prawet Bangkok
# Done 1522: (18.74573303243239,98.9788623259578) Vina Town Condominium, Muang Chiang Mai Chiang Mai
# Done 1523: (13.737703932432392,100.57466512595781) Vincente Sukhumvit 49, Watthana Bangkok
# Done 1524: (13.713821132432393,100.5904561259578) Vinn Sukhumvit 46, Khlong Toei Bangkok
# Done 1525: (13.818887032432393,100.5808613259578) Vino Ratchada 32, Chatuchak Bangkok
# Done 1526: (13.86101827106645,100.51189589287159) Vio Khaerai 1, Muang Nonthaburi Nonthaburi
# Done 1527: (13.856699971066451,100.5122457928716) Vio Khaerai 2, Muang Nonthaburi Nonthaburi
# Done 1528: (13.742875632432392,100.5713850259578) Viscaya Private Residences, Watthana Bangkok
# Done 1529: (13.713774832432392,100.5991383259578) Vista Garden, Watthana Bangkok
# Done 1530: (13.730794032432392,100.5712053259578) Vittorio Sukhumvit 39, Watthana Bangkok
# Done 1531: (13.791783971066451,100.6091427928716) Vivarium Residence, Watthana Bangkok
# Done 1532: (13.658654232432392,100.5986110259578) Vivere Sukhumvit 72, Muang Samut Prakarn Samut Prakarn
# Done 1533: (13.732556932432393,100.6385643259578) Vivid Tower, Suan Luang Bangkok
# Done 1534: (13.723038132432393,100.5789569259578) Von Napa Sukhumvit 38, Khlong Toei Bangkok
# Done 1535: (13.657796532432393,100.6017261259578) Voque Place Sukhumvit 107, Muang Samut Prakarn Samut Prakarn
# Done 1536: (13.727971032432393,100.5607907259578) Voque Sukhumvit 16, Khlong Toei Bangkok
# Done 1537: (13.741837132432392,100.56696942595781) Voque Sukhumvit 31, Watthana Bangkok
# Done 1538: (13.717365632432392,100.5762851259578) Vtara Sukhumvit 36, Khlong Toei Bangkok
# Done 1539: (13.742206832432393,100.5834980259578) W 8 Thonglor 25, Watthana Bangkok
# Done 1540: (13.705969932432392,100.5389071259578) WINDSHELL Naradhiwas, Sathon Bangkok
# Done 1541: (13.712849632432393,100.5942391259578) WYNE Sukhumvit, Watthana Bangkok
# Done 1542: (13.738672832432393,100.5652317259578) Walden Asoke, Watthana Bangkok
# Done 1543: (13.733216332432393,100.5749946259578) Walden Sukhumvit 39, Watthana Bangkok
# Done 1544: (13.730064732432393,100.5828659259578) Walden Thonglor 8, Watthana Bangkok
# Done 1545: (12.57099007106645,99.9602728928716) WanVayla, Hua Hin Prachaubkirikhan
# Done 1546: (12.666518232432393,101.2286850259578) Warunya Executive, Muang Rayong Rayong
# Done 1547: (12.911672132432393,100.8652223259578) Water Park Condominium Pattaya, Bang Lamung Chonburi
# Done 1548: (13.708351132432393,100.5927507259578) Waterford Park Rama 4, Khlong Toei Bangkok
# Done 1549: (13.711128332432393,100.5005513259578) Watermark Chaophraya, Khlong San Bangkok
# Done 1550: (13.743372832432392,100.5585091259578) Wattana Suite, Watthana Bangkok
# Done 1551: (13.740350032432392,100.5613204259578) Watthana Heights, Watthana Bangkok
# Done 1552: (13.858960232432393,100.6539299259578) We Condo Ekkamai-Raminthra, Bang Khen Bangkok
# Done 1553: (13.723268932432392,100.5610804259578) Weltz Residences, Watthana Bangkok
# Done 1554: (12.852580132432392,100.9005340259578) Whale Marina, Sattahip Chonburi
# Done 1555: (13.689417432432393,100.6069923259578) Whizdom @ Punnawithi Station, Phra Khanong Bangkok
# Done 1556: (13.805163032432393,100.5742022259578) Whizdom Avenue Ratchada - Ladprao, Chatuchak Bangkok
# Done 1557: (13.686312432432393,100.6124304259578) Whizdom Connect Sukhumvit, Phra Khanong Bangkok
# Done 1558: (13.685991732432392,100.6122137259578) Whizdom Essence Sukhumvit, Phra Khanong Bangkok
# Done 1559: (13.685613632432393,100.6119365259578) Whizdom Inspire Sukhumvit, Phra Khanong Bangkok
# Done 1560: (13.713841332432393,100.47810182595781) Whizdom Station Ratchada - Thapra, Thon Buri Bangkok
# Done 1561: (13.689766632432393,100.6067801259578) Whizdom The Exclusive Sukhumvit 64, Phra Khanong Bangkok
# Done 1562: (13.728200032432392,100.5650284259578) Wilshire Sukhumvit 22, Khlong Toei Bangkok
# Done 1563: (13.828411332432392,100.5660658259578) Wind Ratchayothin, Chatuchak Bangkok
# Done 1564: (13.739742632432392,100.5643857259578) Wind Sukhumvit 23, Watthana Bangkok
# Done 1565: (13.732861632432392,100.5642610259578) Windsor Tower, Khlong Toei Bangkok
# Done 1566: (13.72948047106645,100.4241599928716) Wisetsuk Nakorn Condo, Bang Khae Bangkok
# Done 1567: (13.732186032432393,100.5265170259578) Wish @ Samyan, Bang Rak Bangkok
# Done 1568: (13.751412832432392,100.5280982259578) Wish @ Siam, Ratchathewi Bangkok
# Done 1569: (13.751896832432392,100.5345428259578) Wish Signature  Midtown Siam, Ratchathewi Bangkok
# Done 1570: (13.750939232432392,100.5352881259578) Wish Signature 2 Midtown Siam, Ratchathewi Bangkok
# Done 1571: (13.748690632432393,100.5492748259578) Wittayu Complex, Ratchathewi Bangkok
# Done 1572: (12.967518632432393,100.8842438259578) Wong Amat Tower, Bang Lamung Chonburi
# Done 1573: (12.967578332432392,100.8852998259578) Wongamat Garden Beach Resort Condominium, Bang Lamung Chonburi
# Done 1574: (12.966320032432392,100.8985469259578) Wongamat Privacy, Bang Lamung Chonburi
# Done 1575: (12.96486247106645,100.8860500928716) Wongamat Residence, Bang Lamung Chonburi
# Done 1576: (7.783115832432393,98.3110954259578) Wyndham Grand Nai Harn Beach Phuket, Muang Phuket Phuket
# Done 1577: (13.723268932432392,100.5610804259578) Wyndham Residence Bangkok, Khlong Toei Bangkok
# Done 1578: (13.894980832432392,100.6119460259578) Wynn Condo  Phahon Yothin 52, Sai Mai Bangkok
# Done 1579: (13.798684132432392,100.5958880259578) Wynn Condo Ladprao - Chokchai 4, Wang Thonglang Bangkok
# Error getting lat,lon at 1580: (0,0) X2 Vibe Phuket Bangtao Condo, Thalang Phuket
# Done 1580: (nan,nan) X2 Vibe Phuket Bangtao Condo, Thalang Phuket
# Done 1581: (13.733606532432393,100.5871926259578) XT EKKAMAI, Watthana Bangkok
# Done 1582: (13.780087332432393,100.5738925259578) XT HUAIKWANG, Huai Khwang Bangkok
# Done 1583: (13.757177932432393,100.5388229259578) XT PHAYATHAI, Ratchathewi Bangkok
# Done 1584: (13.725191632432393,100.5618270259578) XVI The Sixteenth Condominum, Khlong Toei Bangkok
# Done 1585: (13.66038677106645,100.5185054928716) Xim Rama 3 - Suksawat, Phra Pra Daeng Samut Prakarn
# Done 1586: (12.677990832432393,101.2491600259578) Y.E.S. Condo Rayong, Muang Rayong Rayong
# Done 1587: (13.737802332432393,100.5733137259578) Yada Residential, Watthana Bangkok
# Done 1588: (12.922553832432392,100.8755944259578) Yensabai Condotel, Bang Lamung Chonburi
# Done 1589: (13.793646332432392,100.6295675259578) Yensabaidee Ladprao 101, Bang Kapi Bangkok
# Done 1590: (13.808783132432392,100.5712762259578) Yensabaidee Ladprao 15, Chatuchak Bangkok
# Done 1591: (13.69277477106645,100.6379127928716) Yong Charoen Complex, Prawet Bangkok
# Done 1592: (13.836372132432393,100.5822137259578) You 2 Condo, Chatuchak Bangkok
# Done 1593: (13.83858217106645,100.5825685928716) You 3 Condo @ Yak Kaset, Chatuchak Bangkok
# Done 1594: (13.833298932432392,100.5693180259578) Young Place Grand Le Gardine Paholyothin 37, Chatuchak Bangkok
# Done 1595: (13.747230632432393,100.4643014259578) Your Condo Charan 25, Bangkok Noi Bangkok
# Done 1596: (13.191537732432392,100.9334949259578) Yuu Sriracha, Si Racha Chonburi
# Done 1597: (13.810184632432392,100.5668896259578) Z 2 Condominium, Chatuchak Bangkok
# Done 1598: (7.88897267106645,98.3642110928716) Zcape III, Muang Phuket Phuket
# Done 1599: (13.857700332432392,100.5408222259578) Zeen Condo, Muang Nonthaburi Nonthaburi
# Done 1600: (13.870414532432392,100.4859707259578) Zelle Rattanathibet, Muang Nonthaburi Nonthaburi
# Done 1601: (13.870414532432392,100.4859707259578) Zelle Rattanathibet 2, Muang Nonthaburi Nonthaburi
# Done 1602: (13.803022932432393,100.2966909259578) Zelle Salaya, Phuttha Mon Thon Nakhon Pathom
# Done 1603: (13.777153832432392,100.5792750259578) Zenith Place @ Huay Kwang, Huai Khwang Bangkok
# Done 1604: (13.712487432432393,100.5953269259578) Zenith Place @ Sukhumvit, Watthana Bangkok
# Done 1605: (13.716009032432392,100.5861224259578) Zenith Place Sukhumvit 42, Khlong Toei Bangkok
# Done 1606: (12.961488832432392,100.8867276259578) Zire Wongamat, Bang Lamung Chonburi
# Done 1607: (14.06079717106645,100.6102508928716) Zoom Condo Place, Khlong Luang Pathumthani
# Done 1608: (13.756850932432393,100.4776163259578) dBURA Pran Nok, Bangkok Noi Bangkok
# Done 1609: (18.803423832432394,98.9822224259578) dVIENG Santitham Chiangmai, Muang Chiang Mai Chiang Mai
# Done 1610: (13.126410532432393,100.91801992595781) dcondo Bliss Sriracha, Si Racha Chonburi
# Done 1611: (14.060796032432393,100.61025222595781) dcondo Campus Hideaway, Khlong Luang Pathumthani
# Done 1612: (14.022967632432392,99.9921470259578) dcondo Campus Kampangsaen, Kamphaeng Saen Nakhon Pathom
# Done 1613: (13.603626232432392,100.8469401259578) dcondo Campus Resort Bangna, Bang Bo Samut Prakarn
# Done 1614: (13.285735632432392,100.92787542595781) dcondo Campus Resort Bangsaen, Muang Chon Buri Chonburi
# Done 1615: (18.792660732432395,98.9492416259578) dcondo Campus Resort Chiangmai, Muang Chiang Mai Chiang Mai
# Done 1616: (7.906483332432392,98.4032426259578) dcondo Campus Resort Kuku Phuket, Muang Phuket Phuket
# Done 1617: (13.739158032432393,100.4479723259578) dcondo Campus Resort Ratchapruk - Charan 13, Phasi Charoen Bangkok
# Done 1618: (14.061996071066451,100.6082945928716) dcondo Campus Resort Rungsit, Khlong Luang Pathumthani
# Done 1619: (13.77047117106645,100.4696489928716) dcondo Charan - Bangkhunnon, Bangkok Noi Bangkok
# Done 1620: (9.108856471066451,99.3035889928716) dcondo Coco Suratthani, Muang Surat Thani Surat Thani
# Done 1621: (7.909868332432392,98.3472382259578) dcondo Creek Phuket, Kathu Phuket
# Done 1622: (6.983311932432392,100.4777273259578) dcondo Hatyai, Hat Yai Songkhla
# Done 1623: (19.88647533243239,99.8365990259578) dcondo Hyde Chiangrai, Muang Chiang Rai Chiang Rai
# Done 1624: (6.97972017106645,100.4816324928716) dcondo Kanchanavanich Hatyai, Hat Yai Songkhla
# Done 1625: (7.9094593710664505,98.3471782928716) dcondo Kathu, Kathu Phuket
# Done 1626: (7.910270271066451,98.3369927928716) dcondo Kathu - Patong, Kathu Phuket
# Done 1627: (7.907404632432392,98.3550980259578) dcondo Mine Phuket, Kathu Phuket
# Done 1628: (12.681484532432393,101.2420804259578) dcondo Nakorn Rayong, Muang Rayong Rayong
# Done 1629: (18.809679332432395,99.0162332259578) dcondo Nim Chiangmai, Muang Chiang Mai Chiang Mai
# Done 1630: (12.683839332432392,101.2251381259578) dcondo Noenphra Rayong, Muang Rayong Rayong
# Done 1631: (13.730371332432393,100.6997382259578) dcondo Onnut - Rama 9, Prawet Bangkok
# Done 1632: (13.721208032432392,100.7211149259578) dcondo Onnut - Suvarnabhumi, Lat Krabang Bangkok
# Done 1633: (18.81072927106645,99.0158762928716) dcondo Ping, Muang Chiang Mai Chiang Mai
# Done 1634: (13.853559932432393,100.6360795259578) dcondo Ram Intra, Bang Khen Bangkok
# Done 1635: (13.753707271066451,100.6142886928716) dcondo Ramkhamhaeng, Bang Kapi Bangkok
# Done 1636: (13.764786932432392,100.6537564259578) dcondo Ramkhamhaeng 64, Bang Kapi Bangkok
# Done 1637: (13.870202632432392,100.4666294259578) dcondo Rattanathibet, Muang Nonthaburi Nonthaburi
# Done 1638: (13.683338432432393,100.5376668259578) dcondo Sathu Pradit 49, Yan Nawa Bangkok
# Done 1639: (18.80862823243239,99.0161468259578) dcondo Sign Chiangmai, Muang Chiang Mai Chiang Mai
# Done 1640: (13.654093771066451,100.6053168928716) dcondo Sukhumvit 109, Muang Samut Prakarn Samut Prakarn
# Done 1641: (14.061754071066451,100.6093222928716) dcondo campus Dome - Rangsit, Khlong Luang Pathumthani
# Done 1642: (13.772185832432392,100.4581906259578) dcondo panaa, Bangkok Noi Bangkok
# Done 1643: (7.910623732432392,98.3469861259578) dcondo reef phuket, Kathu Phuket
# Done 1644: (18.808082171066452,99.0161941928716) dcondo rin Chiang Mai, Muang Chiang Mai Chiang Mai
# Done 1645: (13.771730532432393,100.4593995259578) dcondo tann Charan, Bangkok Noi Bangkok
# Done 1646: (13.907128132432392,100.5314214259578) de Zone Chaeng Wattana 23, Pak Kret Nonthaburi
# Done 1647: (13.752026071066451,100.5794895928716) i-biza RCA, Huai Khwang Bangkok
# Done 1648: (13.72193077106645,100.7264539928716) iCondo Green Space Sukhumvit 77, Lat Krabang Bangkok
# Done 1649: (13.844846571066451,100.5292210928716) iCondo Ngamwongwan, Muang Nonthaburi Nonthaburi
# Done 1650: (13.83916467106645,100.5241171928716) iCondo Ngamwongwan 2, Muang Nonthaburi Nonthaburi
# Done 1651: (13.709604371066451,100.4296294928716) iCondo Phetkasem 39, Phasi Charoen Bangkok
# Done 1652: (13.71102377106645,100.6380701928716) iCondo Serithai Green Space, Bueng Kum Bangkok
# Done 1653: (13.797732032432393,100.3112956259578) icondo Salaya, Phuttha Mon Thon Nakhon Pathom
# Done 1654: (13.797732032432393,100.3112956259578) icondo Salaya 2 The campus, Phuttha Mon Thon Nakhon Pathom
# Done 1655: (13.885017171066451,100.5999959928716) kensington phaholyothin 63, Bang Khen Bangkok
# Done 1656: (8.068413732432392,98.4417281259578) marina condominium, Muang Phuket Phuket
# Done 1657: (13.742557132432392,100.5548538259578) คริสตัล คอร์ท, Watthana Bangkok
# Done 1658: (13.723969032432393,100.5819933259578) ซานติ ซาดาน, Watthana Bangkok
# Done 1659: (13.72427467106645,100.5721608928716) นีโอ อารีย์, Khlong Toei Bangkok
# Done 1660: (13.576265632432392,100.6045600259578) ออริจิ้น ปลั๊ก แอนด์ เพลย์ อี 22 สเตชั่น, Muang Samut Prakarn Samut Prakarn
# Done 1661: (12.91418017106645,100.8582929928716) อิลิเซี่ยม เรสซิเดนส์, Bang Lamung Chonburi
# Done 1662: (6.976268432432392,100.4819671259578) เดอะ ซิตี้ หาดใหญ่, Hat Yai Songkhla
# Done 1663: (13.956947432432392,100.6221538259578) เดอะ ริเวอร์ พาร์ค โมเดิร์น เพลส, Lam Luk Ka Pathumthani
# Still error getting lat,lon at 1142: (0,0) The Pixels Cape Panwa Condo, Muang Phuket Phuket
# Still error getting lat,lon at 1375: (0,0) Thepharak 3 Housing Baan Eua Ar Thorn  Thepharak 3, Bang Plee Samut Prakarn
# Still error getting lat,lon at 1580: (0,0) X2 Vibe Phuket Bangtao, Thalang Phuket
# ------------------------------
# Results exported
